# %%
import endolas
import h5py
import numpy as np
from matplotlib import pyplot as plt
import imageio
from skimage import io
from skimage import color
import skimage
import json
import tensorflow as tf
from tensorflow.python.keras.saving import hdf5_format

# %% [markdown]
# # Segmentation

# %%
segmentation = '/home/julian/Documents/Studium/MT-Masterarbeit/Workspace/endolas/packages/endolas/resources/segmentation_3_2_best.hdf5'

# %%
hf = h5py.File(segmentation, 'a')
hf.create_dataset('grid_width', data=18)
hf.create_dataset('grid_height', data=18)
hf.close()

# %%
hf = h5py.File(segmentation, 'r')
print(hf.keys())
hf.close()
# Out:
# <KeysViewHDF5 ['grid_height', 'grid_width', 'model_weights', 'optimizer_weights']>

# %%
model = tf.keras.models.load_model(segmentation, compile=False)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 768, 768, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 768, 768, 32) 288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 768, 768, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 768, 768, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 768, 768, 32) 9216        activation[0][0]
# ...

# %% [markdown]
# # Registration

# %%
registration = '/home/julian/Documents/Studium/MT-Masterarbeit/Workspace/endolas/packages/endolas/resources/registration_8_9_60.hdf5'

# %%
hf = h5py.File(registration, 'a')
hf.create_dataset('grid_width', data=18)
hf.create_dataset('grid_height', data=18)
hf.close()

# %%
hf = h5py.File(registration, 'r')
print(hf.keys())
hf.close()
# Out:
# <KeysViewHDF5 ['grid_height', 'grid_width', 'model_weights', 'optimizer_weights']>

# %%
model = tf.keras.models.load_model(registration, compile=False)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 384, 384, 2) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 384, 384, 32) 576         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 384, 384, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 384, 384, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 384, 384, 32) 9216        activation[0][0]
# ...
