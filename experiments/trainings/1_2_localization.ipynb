# %% [markdown]
# # 1.2) Supervised Localization
#
# An EfficientNet is trained here to perform a regression task which assigns a location, that is the x and y position, to each laser point in an image.

# %% [markdown]
# # Import statements
# Following packages are necessary:

# %%
import random
import utils

import tensorflow as tf
import numpy as np
import segmentation_models as sm

from efficientnet.tfkeras import EfficientNetB0

from efficientnet.tfkeras import preprocess_input as pre_eff
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint
from lastengen import LASTENSequence
from matplotlib import pyplot as plt
# Out:
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# # Checks
#
# The version of tensorflow as well as the GPU support are checked.

# %%
print(tf.__version__)
physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2.2.0-rc3
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Data
#
# Import training images

# %%
path_train = r'/home/julian/Documents/Studium/MT-Masterarbeit/Data/LASTEN/train'
path_validation = r'/home/julian/Documents/Studium/MT-Masterarbeit/Data/LASTEN/validation'
path_test = r'/home/julian/Documents/Studium/MT-Masterarbeit/Data/LASTEN/test'

width = 384
height = 384

grid_width = 18
grid_height = 18

# %% [markdown]
# # Seeding
#
# Seeds are set to ensure reproducible training.

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %% [markdown]
# # Network
#
# An EfficientNet network is instantiated with keras to run a regression task.

# %%
base_model = EfficientNetB0(weights=None, include_top=False, input_shape=(height, width, 1), dropout=False)

x = base_model.output
x = GlobalAveragePooling2D()(x)

predictions = Dense(2 * grid_width * grid_height, activation='linear',)(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 384, 384, 1) 0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 192, 192, 32) 288         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 192, 192, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 192, 192, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 192, 192, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 192, 192, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 192, 192, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 192, 192, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 192, 192, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 192, 192, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 192, 192, 96) 1536        block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 192, 192, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 192, 192, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 96, 96, 96)   864         block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 96, 96, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 96, 96, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 96, 96, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 96, 96, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 96, 96, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 96, 96, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 96, 96, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 96, 96, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 96, 96, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 96, 96, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 96, 96, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 96, 96, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 96, 96, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 96, 96, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 96, 96, 24)   0           block2b_project_bn[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 96, 96, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 96, 96, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 96, 96, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 48, 48, 144)  3600        block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 48, 48, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 48, 48, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 48, 48, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 48, 48, 40)   5760        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 48, 48, 40)   160         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 48, 48, 240)  9600        block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 48, 48, 240)  960         block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 48, 48, 240)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 48, 48, 240)  6000        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 48, 48, 240)  960         block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 48, 48, 240)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 48, 48, 240)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 48, 48, 40)   9600        block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 48, 48, 40)   160         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 48, 48, 40)   0           block3b_project_bn[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 48, 48, 240)  9600        block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 48, 48, 240)  960         block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 48, 48, 240)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 24, 24, 240)  2160        block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 24, 24, 240)  960         block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 24, 24, 240)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 24, 24, 240)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 24, 24, 80)   19200       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 24, 24, 80)   320         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 24, 24, 480)  38400       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 24, 24, 480)  1920        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 24, 24, 480)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 24, 24, 480)  4320        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 24, 24, 480)  1920        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 24, 24, 480)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 24, 24, 480)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 24, 24, 80)   38400       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 24, 24, 80)   320         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 24, 24, 80)   0           block4b_project_bn[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 24, 24, 480)  38400       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 24, 24, 480)  1920        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 24, 24, 480)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 24, 24, 480)  4320        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 24, 24, 480)  1920        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 24, 24, 480)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 24, 24, 480)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 24, 24, 80)   38400       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 24, 24, 80)   320         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 24, 24, 80)   0           block4c_project_bn[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 24, 24, 480)  38400       block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 24, 24, 480)  1920        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 24, 24, 480)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 24, 24, 480)  12000       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 24, 24, 480)  1920        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 24, 24, 480)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 24, 24, 480)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 24, 24, 112)  53760       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 24, 24, 112)  448         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 24, 24, 672)  75264       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 24, 24, 672)  2688        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 24, 24, 672)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 24, 24, 672)  16800       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 24, 24, 672)  2688        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 24, 24, 672)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 24, 24, 672)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 24, 24, 112)  75264       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 24, 24, 112)  448         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 24, 24, 112)  0           block5b_project_bn[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 24, 24, 672)  75264       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 24, 24, 672)  2688        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 24, 24, 672)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 24, 24, 672)  16800       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 24, 24, 672)  2688        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 24, 24, 672)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 24, 24, 672)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 24, 24, 112)  75264       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 24, 24, 112)  448         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 24, 24, 112)  0           block5c_project_bn[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_conv (Conv2D)    (None, 24, 24, 672)  75264       block5c_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 24, 24, 672)  2688        block6a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 24, 24, 672)  0           block6a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv (DepthwiseConv2D (None, 12, 12, 672)  16800       block6a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 12, 12, 672)  2688        block6a_dwconv[0][0]
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 12, 12, 672)  0           block6a_bn[0][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[0][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6a_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block6a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6a_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block6a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 12, 12, 672)  0           block6a_activation[0][0]
#                                                                  block6a_se_expand[0][0]
# __________________________________________________________________________________________________
# block6a_project_conv (Conv2D)   (None, 12, 12, 192)  129024      block6a_se_excite[0][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 12, 12, 192)  768         block6a_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_conv (Conv2D)    (None, 12, 12, 1152) 221184      block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 12, 12, 1152) 4608        block6b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 12, 12, 1152) 0           block6b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6b_dwconv (DepthwiseConv2D (None, 12, 12, 1152) 28800       block6b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 12, 12, 1152) 4608        block6b_dwconv[0][0]
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 12, 12, 1152) 0           block6b_bn[0][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[0][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6b_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6b_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 12, 12, 1152) 0           block6b_activation[0][0]
#                                                                  block6b_se_expand[0][0]
# __________________________________________________________________________________________________
# block6b_project_conv (Conv2D)   (None, 12, 12, 192)  221184      block6b_se_excite[0][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 12, 12, 192)  768         block6b_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 12, 12, 192)  0           block6b_project_bn[0][0]
#                                                                  block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_expand_conv (Conv2D)    (None, 12, 12, 1152) 221184      block6b_add[0][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 12, 12, 1152) 4608        block6c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 12, 12, 1152) 0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 12, 12, 1152) 28800       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 12, 12, 1152) 4608        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 12, 12, 1152) 0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 12, 12, 1152) 0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 12, 12, 192)  221184      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 12, 12, 192)  768         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 12, 12, 192)  0           block6c_project_bn[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 12, 12, 1152) 221184      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 12, 12, 1152) 4608        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 12, 12, 1152) 0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 12, 12, 1152) 28800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 12, 12, 1152) 4608        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 12, 12, 1152) 0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 12, 12, 1152) 0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 12, 12, 192)  221184      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 12, 12, 192)  768         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 12, 12, 192)  0           block6d_project_bn[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 12, 12, 1152) 221184      block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 12, 12, 1152) 4608        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 12, 12, 1152) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 12, 12, 1152) 10368       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 12, 12, 1152) 4608        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 12, 12, 1152) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 12, 12, 1152) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 12, 12, 320)  368640      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 12, 12, 320)  1280        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 12, 12, 1280) 409600      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 12, 12, 1280) 5120        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 12, 12, 1280) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           top_activation[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 648)          830088      global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 4,879,076
# Trainable params: 4,837,060
# Non-trainable params: 42,016
# __________________________________________________________________________________________________

# %% [markdown]
# # Data Preparation
#
# The generator sequence for training is built.

# %%
image_ids = [3]

train_gen = LASTENSequence(path_train,
                           batch_size=1,
                           image_ids=image_ids,
                           preprocess_input=pre_eff,
                           shuffle=False,
                           augment=False,
                           width=width,
                           height=height,
                           label="keypoints")

#validation_gen = LASTENSequence(path_validation,
#                                batch_size=8,
#                                preprocess_input=pre_une,
#                                width=width,
#                                height=height)

#test_gen = LASTENSequence(path_train,
#                          batch_size=8,
#                          preprocess_input=pre_une,
#                          width=width,
#                          height=height)

# %% [markdown]
# # Training Preparation
#
# Prepare the settings for training the model.

# %%
logger = CSVLogger("experiments/localization.log")
checker = ModelCheckpoint("experiments/localization/weights.{epoch:02d}.hdf5",
                          period=50)

callbacks = [logger, checker]

model.compile(optimizer='adam', loss='mse', metrics=['mape'])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# # Training
#
# The model is fitted with a generator.

# %%
model.fit_generator(train_gen,
                    epochs=3000,
                    callbacks=callbacks,
                    validation_data=train_gen,
                    validation_freq=1,
                    use_multiprocessing=False,
                    workers=10,
                    max_queue_size=32)
# Out:
# WARNING:tensorflow:From <ipython-input-8-c05ed6e768f9>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/3000
# 1/1 [==============================] - 2s 2s/step - loss: 2.2876 - mape: 100.4505 - val_loss: 2.2044 - val_mape: 99.8884
# Epoch 2/3000
# 1/1 [==============================] - 0s 343ms/step - loss: 1.6099 - mape: 83.3391 - val_loss: 2.1994 - val_mape: 99.7733
# Epoch 3/3000
# 1/1 [==============================] - 0s 345ms/step - loss: 1.0375 - mape: 65.3042 - val_loss: 2.1933 - val_mape: 99.6311
# Epoch 4/3000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.5903 - mape: 47.0919 - val_loss: 2.1856 - val_mape: 99.4500
# Epoch 5/3000
# 1/1 [==============================] - 0s 338ms/step - loss: 0.2839 - mape: 30.2536 - val_loss: 2.1758 - val_mape: 99.2197
# Epoch 6/3000
# 1/1 [==============================] - 0s 339ms/step - loss: 0.1153 - mape: 18.0455 - val_loss: 2.1640 - val_mape: 98.9411
# Epoch 7/3000
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0601 - mape: 14.0360 - val_loss: 2.1510 - val_mape: 98.6378
# Epoch 8/3000
3000
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0022 - mape: 2.8848 - val_loss: 2.1206 - val_mape: 97.9390
# Epoch 32/3000
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0023 - mape: 2.9716 - val_loss: 2.1201 - val_mape: 97.9239
# Epoch 33/3000
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0020 - mape: 2.7692 - val_loss: 2.1190 - val_mape: 97.8973
# Epoch 34/3000
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0017 - mape: 2.4900 - val_loss: 2.1178 - val_mape: 97.8665
# Epoch 35/3000
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0017 - mape: 2.3841 - val_loss: 2.1167 - val_mape: 97.8400
# Epoch 36/3000
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0018 - mape: 2.4216 - val_loss: 2.1160 - val_mape: 97.8238
# Epoch 37/3000
# 1/1 [==============================] - 0s 340ms/step - loss: 0.0018 - mape: 2.4031 - val_loss: 2.1158 - val_mape: 97.8187
# Epoch 38/3000
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0015 - mape: 2.2891 - val_loss: 2.1159 - val_mape: 97.8206
# Epoch 39/3000
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0012 - mape: 2.1497 - val_loss: 2.1160 - val_mape: 97.8223
# Epoch 40/3000
# 1/1 [==============================] - 0s 338ms/step - loss: 0.0011 - mape: 2.0223 - val_loss: 2.1157 - val_mape: 97.8175
# Epoch 41/3000
# 1/1 [==============================] - 0s 335ms/step - loss: 0.0011 - mape: 1.8935 - val_loss: 2.1151 - val_mape: 97.8027
# Epoch 42/3000
# 1/1 [==============================] - 0s 335ms/step - loss: 9.8930e-04 - mape: 1.7349 - val_loss: 2.1141 - val_mape: 97.7784
# Epoch 43/3000
# 1/1 [==============================] - 0s 336ms/step - loss: 7.7730e-04 - mape: 1.5616 - val_loss: 2.1128 - val_mape: 97.7485
# Epoch 44/3000
# 1/1 [==============================] - 0s 336ms/step - loss: 6.3070e-04 - mape: 1.4658 - val_loss: 2.1116 - val_mape: 97.7193
# Epoch 45/3000
# 1/1 [==============================] - 0s 336ms/step - loss: 6.1306e-04 - mape: 1.4937 - val_loss: 2.1106 - val_mape: 97.6963
# Epoch 46/3000
# 1/1 [==============================] - 0s 338ms/step - loss: 6.2067e-04 - mape: 1.5182 - val_loss: 2.1100 - val_mape: 97.6821
# Epoch 47/3000
# 1/1 [==============================] - 0s 335ms/step - loss: 5.5029e-04 - mape: 1.4337 - val_loss: 2.1097 - val_mape: 97.6753
# Epoch 48/3000
# 1/1 [==============================] - 0s 337ms/step - loss: 4.3818e-04 - mape: 1.2603 - val_loss: 2.1096 - val_mape: 97.6714
# Epoch 49/3000
# 1/1 [==============================] - 0s 335ms/step - loss: 3.8274e-04 - mape: 1.1168 - val_loss: 2.1093 - val_mape: 97.6649
# Epoch 50/3000
# 1/1 [==============================] - 1s 1s/step - loss: 3.9411e-04 - mape: 1.0783 - val_loss: 2.1088 - val_mape: 97.6516
# Epoch 51/3000
# 1/1 [==============================] - 0s 339ms/step - loss: 3.9304e-04 - mape: 1.0696 - val_loss: 2.1079 - val_mape: 97.6302
# Epoch 52/3000
# 1/1 [==============================] - 0s 339ms/step - loss: 3.3611e-04 - mape: 1.0097 - val_loss: 2.1068 - val_mape: 97.6027
# Epoch 53/3000
# 1/1 [==============================] - 0s 340ms/step - loss: 2.6927e-04 - mape: 0.9469 - val_loss: 2.1056 - val_mape: 97.5731
# Epoch 54/3000
# 1/1 [==============================] - 0s 338ms/step - loss: 2.4642e-04 - mape: 0.9472 - val_loss: 2.1045 - val_mape: 97.5461
# Epoch 55/3000
# 1/1 [==============================] - 0s 337ms/step - loss:
3000
# 1/1 [==============================] - 0s 337ms/step - loss: 1.2955e-14 - mape: 4.8593e-06 - val_loss: 0.0053 - val_mape: 4.8995
# Epoch 2985/3000
# 1/1 [==============================] - 0s 338ms/step - loss: 1.1245e-14 - mape: 4.7734e-06 - val_loss: 0.0054 - val_mape: 4.9146
# Epoch 2986/3000
# 1/1 [==============================] - 0s 336ms/step - loss: 1.0735e-14 - mape: 4.5824e-06 - val_loss: 0.0054 - val_mape: 4.9295
# Epoch 2987/3000
# 1/1 [==============================] - 0s 339ms/step - loss: 1.2506e-14 - mape: 4.8022e-06 - val_loss: 0.0054 - val_mape: 4.9443
# Epoch 2988/3000
# 1/1 [==============================] - 0s 336ms/step - loss: 1.3175e-14 - mape: 5.4271e-06 - val_loss: 0.0055 - val_mape: 4.9589
# Epoch 2989/3000
# 1/1 [==============================] - 0s 339ms/step - loss: 1.1376e-14 - mape: 4.7740e-06 - val_loss: 0.0055 - val_mape: 4.9734
# Epoch 2990/3000
# 1/1 [==============================] - 0s 338ms/step - loss: 1.2012e-14 - mape: 4.9796e-06 - val_loss: 0.0055 - val_mape: 4.9877
# Epoch 2991/3000
# 1/1 [==============================] - 0s 340ms/step - loss: 1.2319e-14 - mape: 4.8125e-06 - val_loss: 0.0056 - val_mape: 5.0019
# Epoch 2992/3000
# 1/1 [==============================] - 0s 334ms/step - loss: 1.1820e-14 - mape: 4.7535e-06 - val_loss: 0.0056 - val_mape: 5.0159
# Epoch 2993/3000
# 1/1 [==============================] - 0s 339ms/step - loss: 1.3219e-14 - mape: 5.1159e-06 - val_loss: 0.0056 - val_mape: 5.0298
# Epoch 2994/3000
# 1/1 [==============================] - 0s 338ms/step - loss: 1.3679e-14 - mape: 5.2457e-06 - val_loss: 0.0056 - val_mape: 5.0436
# Epoch 2995/3000
# 1/1 [==============================] - 0s 344ms/step - loss: 1.2462e-14 - mape: 4.9401e-06 - val_loss: 0.0057 - val_mape: 5.0572
# Epoch 2996/3000
# 1/1 [==============================] - 0s 334ms/step - loss: 1.2210e-14 - mape: 4.7775e-06 - val_loss: 0.0057 - val_mape: 5.0707
# Epoch 2997/3000
# 1/1 [==============================] - 0s 339ms/step - loss: 1.2347e-14 - mape: 4.8665e-06 - val_loss: 0.0057 - val_mape: 5.0840
# Epoch 2998/3000
# 1/1 [==============================] - 0s 336ms/step - loss: 1.4737e-14 - mape: 5.4387e-06 - val_loss: 0.0058 - val_mape: 5.0972
# Epoch 2999/3000
# 1/1 [==============================] - 0s 337ms/step - loss: 1.2456e-14 - mape: 5.0120e-06 - val_loss: 0.0058 - val_mape: 5.1103
# Epoch 3000/3000
# 1/1 [==============================] - 1s 1s/step - loss: 1.3361e-14 - mape: 5.1381e-06 - val_loss: 0.0058 - val_mape: 5.1232

# %%
X, y = train_gen[0]
y_pred = model.predict(X)

# %%
plt.rcParams['figure.figsize'] = (15, 15)

# %%
image = X[0]
keypoints = y_pred[0]

plt.clf()
plt.imshow(image[:,:,0], cmap="gray")

x_list = []
y_list = []

for index in range(0, 18*18):
    x_index = index * 2 
    
    x = (keypoints[x_index] - 1) * width
    y = (keypoints[x_index + 1] - 1) * height
    
    x_list.append(x)
    y_list.append(y)
    
    
plt.scatter(x_list, y_list,s=80,facecolors='none', edgecolors='r')
