# %% [markdown]
# # Variational Autoencoder for Augmentation of Laser-Based Laryngeal Imaging
#
# For the deep-learning-based algorithm to match features via a registration task, it is essential to apply intense data augmentation to the training data set. As displayed in the following figure the training data consists of images $m(x)$ that represent the spatial configuration of laser points projected onto the vocal fold surface.
#
# ![alt text here](images/feature_matching_registration.png "Logo Title Jupyter Notebook logo")
#
# The foundation for the images $m(x)$ are the x-y-coordinates of each single laser point within the image, as $m(x)$ is generated by plotting the single laser points and then smoothing the image. To create intense augmentation we want to train a variational autoencoder (VAE) to then generate images that are variations of the images of the training set and represent feasible configurations of laser points projected onto a vocal fold. The implementation of the VAE is inspired by [Keras](https://keras.io/examples/generative/vae/).
#
# In a VAE a decoder-encoder architecture is utilized. The coding is split up into a vector representing the mean $\mu$
# of a distribution over a latent space. The distribution is assumed to be gaussian. Therefore, a second vector exists as a coding representing the variance $\mathbf{\sigma^2}$. Behind the coding a sampling layer exists that randomly samples a value from the distribution given by $\mathcal{N}(\mu,\,\sigma^{2})$. Like that it is possible to create a smooth latent space. The network can be trained in a unsupervised manner, as the the decoder should learn to reconstruct the input of the encoder as good as possible. After training, only the decoder part will be used. Inputing random points in the latent space will then generate x- and y-coordinates that are part of the underlying trained distribution based on the ground truth.

# %% [markdown]
# ## Import Statements
# The notebook was developed on Keras using the Tensorflow 2.2.0 backend.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
from scipy.ndimage import gaussian_filter
from tensorflow.keras.callbacks import CSVLogger
from sklearn.manifold import TSNE

# %% [markdown]
# ## Hardware Configuration
# Check for GPU and allow memory growth such that limitations for training are reduced.

# %%
if len(tf.config.experimental.get_visible_devices('GPU')):
    physical_devices = tf.config.experimental.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Functionality
# The following functionality helps to create the images for training the registration task.

# %%
def apply_smoothing(image, sigma=1.0, sigma_back=10.0):
    image_orig = image
    image = gaussian_filter(image, sigma=sigma)
    image_back = gaussian_filter(image, sigma=sigma_back)

    image = (image / image.max()) * 255
    image_back = (image_back / image_back.max()) * 255
    image = 0.3 * image_orig + 0.3 * image + 0.3 * image_back

    return image

# %%
def reconstruct_image(x_position, y_position):
    image = np.zeros((image_height, image_width))
    for x, y in zip(x_position.flatten(), y_position.flatten()):
        x = int(x*image_width)
        y = int(y*image_height)
        
        if x >= 5 and y>= 5:
            image[y][x] = 1
        
    image = apply_smoothing(image, sigma=2, sigma_back=15)
    return image

# %% [markdown]
# ## Model parameters
# The grid dimensions have to be know, as well as the image dimensions for scaling. The depth of the input and output layer is 2 here, as we will have one channel representing x-coordinates and a second channel representing y-coordinates.

# %%
grid_width = 18
grid_height = 18

image_width = 728
image_height = 728

inout_layers = 2

# %% [markdown]
# ## Hyperparameters
# The dimension of the latent space can be adapted to optimize the network.

# %%
latent_dim = 8
epochs = 200
batch_size = 4
coding_loss_factor = 1.0
epsilon_factor = 1.0

# %% [markdown]
# ## Sampling Layer
# In the sampling layer the coding $\mathbf{\mu}$ and $\log{(\mathbf{\sigma^2})}$ are used to randomly sample a point from the underlying distribution. Due to this randomness that occurs within each batch and along all epochs the decoder is trained on smooth distributions. Each coding $\mathbf{c}$ used to train the decoder is computed as
#
# $$\mathbf{c} = \mathbf{\mu} + e^{0.5\mathbf{\log{(\mathbf{\sigma^2})}}}\mathbf{\epsilon}f$$
#
# where $\epsilon$ is a random vector with entries between 0 and 1 and $f$ is a hyperparameter to control the amount of randomness.

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon * epsilon_factor

# %%
dense_units = 100

# %% [markdown]
# ## Encoder Model
# In the encoder strided convolutional layers are applied to reduce the dimensionality of the input. For a grid with dimension 18x18 the input shape is increased to 20x20 and the input images are padded. Like that it is easier to ensure symmetry between encoder an decoder. The encoder is a keras model having the mean, variance and a sampled value as output.

# %%
encoder_inputs = keras.Input(shape=(grid_width+2, grid_height+2, inout_layers))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)

#x = layers.Flatten()(encoder_inputs)
#x = layers.Dense(dense_units, activation="relu")(x)
#x = layers.Dense(dense_units, activation="relu")(x)

z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 20, 20, 2)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 10, 10, 32)   608         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 5, 64)     18496       conv2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1600)         0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           25616       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 8)            136         dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 8)            136         dense[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 8)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 44,992
# Trainable params: 44,992
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Decoder Model
# The decoder takes only a sampeled value or a randomly selected value with the size of the latent space as input.
# The dimnesion of the input of the encoder is then reconstructed. The decoder is constructed as a keras model.

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
y_val = (grid_height+2)//4
x_val = (grid_width+2)//4

x = layers.Dense(y_val*x_val*64, activation="relu")(latent_inputs)
x = layers.Reshape((y_val, x_val, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(inout_layers, 3, activation="sigmoid", padding="same")(x)

#x = layers.Dense(dense_units, activation="relu")(latent_inputs)
#x = layers.Dense(dense_units, activation="relu")(x)
#x = layers.Dense((grid_height+2)*(grid_width+2)*inout_layers, activation="linear")(x)
#decoder_outputs = layers.Reshape((grid_height+2, grid_width+2, inout_layers))(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1600)              14400
# _________________________________________________________________
# reshape (Reshape)            (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 10, 10, 64)        36928
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 20, 20, 32)        18464
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 20, 20, 2)         578
# =================================================================
# Total params: 70,370
# Trainable params: 70,370
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## VAE Model
# The VAE is composed by the encoder and decoder. The decoder only takes the random coding $\mathbf{c}$ from the encoder. However, the codings $\mathbf{\mu}$ and $\log{(\mathbf{\sigma^2})}$ are used to compute a loss for regularizing and ensuring a smooth distribution. The coding loss is:
#
# $$ \epsilon_{coding} = 1 + \log{(\sigma^2)} - \mu^2 - \sigma^2 $$
#
# A binary crossentropy is used to define a reconstruction loss $\epsilon_{reconstruction}$.
# We are doing a regression here, based on probabilities. Therefore, cross entropy needs to be applied. See
# [Explanation](
# https://stats.stackexchange.com/questions/223256/does-the-cross-entropy-cost-make-sense-in-the-context-of-regression). The overall loss is then:
#
# $$\epsilon = \epsilon_{reconstruction} - \epsilon_{coding}$$

# %%
class VariationalAutoEncoder(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VariationalAutoEncoder, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
            
        # Gradient tape allows to "record" a function that will be derived
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = encoder(data)
            
            # Reconstuction Loss
            reconstruction = decoder(z_mean)
            reconstruction_loss = tf.reduce_mean(
                keras.losses.mean_squared_error(data, reconstruction)
                #keras.losses.binary_crossentropy(data, reconstruction)
            )
            reconstruction_loss *= grid_height+2 * grid_height+2
            
            # Regularization Loss for well formed latent space and no overfitting
            #coding_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            #coding_loss = tf.reduce_mean(coding_loss)
            #coding_loss *= -(0.2 * coding_loss_factor)
            
            # Total Loss
            total_loss = reconstruction_loss #+ coding_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            #"coding_loss": coding_loss,
        }

# %% [markdown]
# ## Prepare data
# Load the data and scale them to be between 0.0 an 1.0. Further use zero-padding to get a 20x20 shape for this example. We use the already augmented data here for providing a large training set.

# %%
x_position = np.load('data/x_pos_LASTEN2.npy')
y_position = np.load('data/y_pos_LASTEN2.npy')

offset = 0.0

# Non existing points mapping
x_position = np.where(x_position<=0, -offset, x_position) + offset
y_position = np.where(x_position<=0, -offset, y_position) + offset

x_position = x_position / (image_width + offset)
y_position = y_position / (image_height + offset)

# Zero padding
x_position = np.pad(x_position,[(0,0),(1,1),(1,1)],constant_values=0)
y_position = np.pad(y_position,[(0,0),(1,1),(1,1)],constant_values=0)

x_position = x_position[:,:,:,np.newaxis]
y_position = y_position[:,:,:,np.newaxis]

xy_data = np.concatenate((x_position, y_position), axis=3)
print("Shape of 'xy_data': {}".format(xy_data.shape))
# Out:
# Shape of 'xy_data': (160, 20, 20, 2)

# %% [markdown]
# ## Training
# Initialize the VAE, compile it and fit the model.

# %%
history = None

vae = VariationalAutoEncoder(encoder, decoder)

vae.compile(optimizer=keras.optimizers.Adam())
#logger = CSVLogger("VAE_log")
history = vae.fit(xy_data, epochs=epochs, batch_size=batch_size)
#vae.save_weights('weights/vae/vae_100_epochs_gt')

#vae.load_weights('weights/vae/vae_100_epochs_gt')
# Out:
# Epoch 1/200
# WARNING:tensorflow:Gradients do not exist for variables ['z_log_var/kernel:0', 'z_log_var/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['z_log_var/kernel:0', 'z_log_var/bias:0'] when minimizing the loss.
# 40/40 [==============================] - 0s 4ms/step - loss: 4.6839 - reconstruction_loss: 4.6839
# Epoch 2/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7019 - reconstruction_loss: 0.7019
# Epoch 3/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4245 - reconstruction_loss: 0.4245
# Epoch 4/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4015 - reconstruction_loss: 0.4015
# Epoch 5/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3771 - reconstruction_loss: 0.3771
# Epoch 6/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3825 - reconstruction_loss: 0.3825
# Epoch 7/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3776 - reconstruction_loss: 0.3776
# Epoch 8/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3776 - reconstruction_loss: 0.3776
# Epoch 9/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3697 - reconstruction_loss: 0.3697
# Epoch 10/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3719 - reconstruction_loss: 0.3719
# Epoch 11/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3627 - reconstruction_loss: 0.3627
# Epoch 12/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3444 - reconstruction_loss: 0.3444
# Epoch 13/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3198 - reconstruction_loss: 0.3198
# Epoch 14/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2944 - reconstruction_loss: 0.2944
# Epoch 15/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2762 - reconstruction_loss: 0.2762
# Epoch 16/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2575 - reconstruction_loss: 0.2575
# Epoch 17/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2414 - reconstruction_loss: 0.2414
# Epoch 18/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2326 - reconstruction_loss: 0.2326
# Epoch 19/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2144 - reconstruction_loss: 0.2144
# Epoch 20/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1986 - reconstruction_loss: 0.1986
# Epoch 21/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1820 - reconstruction_loss: 0.1820
# Epoch 22/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1682 - reconstruction_loss: 0.1682
# Epoch 23/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1518 - reconstruction_loss: 0.1518
# Epoch 24/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1473 - reconstruction_loss: 0.1473
# Epoch 25/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1444 - reconstruction_loss: 0.1444
# Epoch 26/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1299 - reconstruction_loss: 0.1299
# Epoch 27/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1220 - reconstruction_loss: 0.1220
# Epoch 28/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1325 - reconstruction_loss: 0.1325
# Epoch 29/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1154 - reconstruction_loss: 0.1154
# Epoch 30/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1084 - reconstruction_loss: 0.1084
# Epoch 31/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1052 - reconstruction_loss: 0.1052
# Epoch 32/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1018 - reconstruction_loss: 0.1018
# Epoch 33/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0959 - reconstruction_loss: 0.0959
# Epoch 34/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0957 - reconstruction_loss: 0.0957
# Epoch 35/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0920 - reconstruction_loss: 0.0920
# Epoch 36/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0879 - reconstruction_loss: 0.0879
# Epoch 37/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0880 - reconstruction_loss: 0.0880
# Epoch 38/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0841 - reconstruction_loss: 0.0841
# Epoch 39/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0798 - reconstruction_loss: 0.0798
# Epoch 40/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0757 - reconstruction_loss: 0.0757
# Epoch 41/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0813 - reconstruction_loss: 0.0813
# Epoch 42/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0740 - reconstruction_loss: 0.0740
# Epoch 43/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0706 - reconstruction_loss: 0.0706
# Epoch 44/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0735 - reconstruction_loss: 0.0735
# Epoch 45/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0678 - reconstruction_loss: 0.0678
# Epoch 46/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0681 - reconstruction_loss: 0.0681
# Epoch 47/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0705 - reconstruction_loss: 0.0705
# Epoch 48/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0769 - reconstruction_loss: 0.0769
# Epoch 49/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0633 - reconstruction_loss: 0.0633
# Epoch 50/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0618 - reconstruction_loss: 0.0618
# Epoch 51/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0580 - reconstruction_loss: 0.0580
# Epoch 52/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0541 - reconstruction_loss: 0.0541
# Epoch 53/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0534 - reconstruction_loss: 0.0534
# Epoch 54/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0565 - reconstruction_loss: 0.0565
# Epoch 55/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0592 - reconstruction_loss: 0.0592
# Epoch 56/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0547 - reconstruction_loss: 0.0547
# Epoch 57/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0505 - reconstruction_loss: 0.0505
# Epoch 58/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0504 - reconstruction_loss: 0.0504
# Epoch 59/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0871 - reconstruction_loss: 0.0871
# Epoch 60/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0785 - reconstruction_loss: 0.0785
# Epoch 61/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0670 - reconstruction_loss: 0.0670
# Epoch 62/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0485 - reconstruction_loss: 0.0485
# Epoch 63/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0447 - reconstruction_loss: 0.0447
# Epoch 64/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0444 - reconstruction_loss: 0.0444
# Epoch 65/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0441 - reconstruction_loss: 0.0441
# Epoch 66/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0457 - reconstruction_loss: 0.0457
# Epoch 67/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0409 - reconstruction_loss: 0.0409
# Epoch 68/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0423 - reconstruction_loss: 0.0423
# Epoch 69/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0394 - reconstruction_loss: 0.0394
# Epoch 70/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0393 - reconstruction_loss: 0.0393
# Epoch 71/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0405 - reconstruction_loss: 0.0405
# Epoch 72/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0393 - reconstruction_loss: 0.0393
# Epoch 73/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0389 - reconstruction_loss: 0.0389
# Epoch 74/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0364 - reconstruction_loss: 0.0364
# Epoch 75/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0367 - reconstruction_loss: 0.0367
# Epoch 76/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.
200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0185 - reconstruction_loss: 0.0185
# Epoch 182/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0192 - reconstruction_loss: 0.0192
# Epoch 183/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0195 - reconstruction_loss: 0.0195
# Epoch 184/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0174 - reconstruction_loss: 0.0174
# Epoch 185/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0170 - reconstruction_loss: 0.0170
# Epoch 186/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0159 - reconstruction_loss: 0.0159
# Epoch 187/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0138 - reconstruction_loss: 0.0138
# Epoch 188/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0146 - reconstruction_loss: 0.0146
# Epoch 189/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0144 - reconstruction_loss: 0.0144
# Epoch 190/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0148 - reconstruction_loss: 0.0148
# Epoch 191/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0149 - reconstruction_loss: 0.0149
# Epoch 192/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0152 - reconstruction_loss: 0.0152
# Epoch 193/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0166 - reconstruction_loss: 0.0166
# Epoch 194/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0150 - reconstruction_loss: 0.0150
# Epoch 195/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0160 - reconstruction_loss: 0.0160
# Epoch 196/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0373 - reconstruction_loss: 0.0373
# Epoch 197/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0666 - reconstruction_loss: 0.0666
# Epoch 198/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0262 - reconstruction_loss: 0.0262
# Epoch 199/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0157 - reconstruction_loss: 0.0157
# Epoch 200/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0140 - reconstruction_loss: 0.0140

# %%
if history:
    print('Mean reconstruction loss over last 20 epochs: {}'.format(np.array(history.history['reconstruction_loss'][-20:]).mean()))
    #print('Mean coding loss over last 20 epochs: {}'.format(np.array(history.history['coding_loss'][-20:]).mean()))
    plt.semilogy(history.history['reconstruction_loss'], label='Reconstruction Loss')
    plt.title('Crossentropy Loss for Reconstruction of Input images')
    plt.ylabel('Crossentropy')
    plt.xlabel('No. epoch')
    plt.legend(loc="upper left")
    plt.show()
# Out:
# Mean reconstruction loss over last 20 epochs: 0.021760743844788523

# %% [markdown]
# ## Predict images and compare with ground truth
# Get the mean value for ground truth images and decode the value to reconstruct the images.

# %%
res_encoder = encoder.predict(xy_data)[0]
res_decoder = decoder.predict(res_encoder)
plt.rcParams["figure.figsize"] = (7,7)

# %% [markdown]
# ### Predicition of x-coordinates by autoencoder
# Out of all 8 recordings from the dataset one frame is displayed

# %%
for i in range(8):
    val = 441 + i
    plt.subplot(val)
    x = res_decoder[i*20,:,:,0]
    plt.imshow(x)
    plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# ### Ground-truth of x-coordinates
# Out of all 8 recordings from the dataset one frame is displayed.

# %%
for i in range(8):
    val = 441 + i
    plt.subplot(val)
    x = xy_data[i*20,:,:,0]
    plt.imshow(x)
    plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# ### Predicition of x-y-coordinates and display in image space
# Out of all 8 recordings from the dataset one frame is displayed

# %%
for i in range(8):
    val = 441 + i
    plt.subplot(val)
    x = res_decoder[i*20,:,:,0]
    y = res_decoder[i*20,:,:,1]
    plt.imshow(reconstruct_image(x, y),cmap='gist_gray')
    plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# ### Ground truth of x-y-coordinates and display in image space
# Out of all 8 recordings from the dataset one frame is displayed

# %%
for i in range(8):
    val = 441 + i
    plt.subplot(val)
    x = xy_data[i*20,:,:,0]
    y = xy_data[i*20,:,:,1]
    plt.imshow(reconstruct_image(x, y),cmap='gist_gray')
    plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# ## Postprocessing
# We apply a bilateral filter to denoise the coordinate images. Further irregularities in x- and y-direction are removed.

# %%
from skimage.restoration import denoise_bilateral
plt.rcParams["figure.figsize"] = (7,7)

def postprocess_coordinate_images(results, index):
    x = results[index,:,:,0]
    y = results[index,:,:,1]
    
    # Unpad
    x = x[1:-1,1:-1]
    y = y[1:-1,1:-1]
    
    x_max_orig = x.max()
    y_max_orig = y.max()
    
    # Smooth and equalize possible offset due to smoothing
    x = denoise_bilateral(x, mode='edge',sigma_spatial=100, win_size=3)
    y = denoise_bilateral(y, mode='edge',sigma_spatial=100, win_size=3)
    x = x - x.min()
    y = y - y.min()
    x = x * (x_max_orig / x.max())
    y = y * (y_max_orig / y.max())
    
    # Sort out irregularities in x
    for i in range(len(x)):        
        max_value=0.0
        for j in range(len(x[i])):
            if x[i][j] <= max_value:
                x[i][j] = 0.0
                y[i][j] = 0.0
            else: 
                max_value = x[i][j]
            
    # Sort out irregularities in y
    for i in range(len(y[0])):        
        max_value=0.0
        for j in reversed(range(len(y))):
            if y[j][i] <= max_value:
                x[j][i] = 0.0
                y[j][i] = 0.0
            else:
                max_value = y[j][i]
    
    return x, y

# %% [markdown]
# ## Predict codings based on the training data

# %%
res_encoder = encoder.predict(xy_data)

# %% [markdown]
# ## Generate an image based on a vector from the latent space
# Use this functionality to explore the latent space.

# %%
# %%capture
# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interact, widgets
from IPython.display import display

def f(**sliders):
    image_id = 0
    
    sliders_float = [float(slider[1]) for slider in sliders.items()]
    
    res_encoder_offset = np.array([sliders_float])
    res_decoder = decoder.predict(res_encoder[0][image_id] + res_encoder_offset)
    
    x, y = postprocess_coordinate_images(res_decoder, image_id)

    img = reconstruct_image(x, y)
    ax.imshow(img, cmap="gray")
    display(fig)

fig = plt.figure(figsize=(6, 4))
ax = fig.add_axes(plt.axes())
fig.canvas.draw()
ax.axis('off')


sliders = {str(i): widgets.FloatSlider(min=-2.0,max=2.0,step=0.5,value=0.0, continuous_update=False) for i in range(latent_dim)}

# %%
_ = interact(f, **sliders)
# Out:
# interactive(children=(FloatSlider(value=0.0, continuous_update=False, description='0', max=2.0, min=-2.0, step…

# %% [markdown]
# ## Draw samples from the distribution
# First we want to have a look, how the data is distributed. We highlight the first frame of all recordings as they mainly define the data set.

# %%
plt.rcParams["figure.figsize"] = (7,7)

dim1 = res_encoder[0][:,0]
dim2 = res_encoder[0][:,1]
dim3 = res_encoder[0][:,2]
dim4 = res_encoder[0][:,3]
dim5 = res_encoder[0][:,4]
dim6 = res_encoder[0][:,5]
dim7 = res_encoder[0][:,6]
dim8 = res_encoder[0][:,7]

dim = dim2

plt.scatter(dim1, dim)
for i in range(8):
    image_id = i*18
    plt.scatter(dim1[image_id], dim[image_id],c='r')
    plt.text(dim1[image_id], dim[image_id], str(image_id))

# %% [markdown]
# There are several possibilties to draw samples from the latent space.
# 1. Predict the latent vector of one sample image and pertubate it.
# 2. Linearly Interpolate between neighbors.
# 3. Linearly Extrapolate with neighbors. (Not discussed here)

# %% [markdown]
# ### 1. Predict the latent vector of one sample image and pertubate it.
# Pertubation is computed as a value from a normal distribution with zero mean. A coding $\hat{\mathbf{c}}$ can be sampled as:
# $$\hat{\mathbf{c}} = \mathbf{\mu} + e^{0.5\mathbf{\log{(\mathbf{\sigma^2})}}}\mathbf{\epsilon}f$$
#
# where $\mathbf{\epsilon}$ is a random value from a normal distribution and $f$ allows us to control the amount of pertubation.

# %%
plt.rcParams["figure.figsize"] = (7,7)

image_id = 18

epsilon = np.random.normal(size=res_encoder[0].shape)
variation = res_encoder[0]+np.exp(0.5 * res_encoder[1]) * epsilon

res_decoder = decoder.predict(variation)
new_x, new_y = postprocess_coordinate_images(res_decoder, image_id)
plt.imshow(reconstruct_image(new_x, new_y),cmap='gist_gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f590800afac3> in <module>
#       7
#       8 res_decoder = decoder.predict(variation)
# ----> 9 new_x, new_y = postprocess_coordinate_images(res_decoder, image_id)
#      10 plt.imshow(reconstruct_image(new_x, new_y),cmap='gist_gray')
#
# <ipython-input-20-48fec7a2bdaa> in postprocess_coordinate_images(results, index)
#      14
#      15     # Smooth and equalize possible offset due to smoothing
# ---> 16     x = denoise_bilateral(x, mode='edge',sigma_spatial=100, win_size=3)
#      17     y = denoise_bilateral(y, mode='edge',sigma_spatial=100, win_size=3)
#      18     x = x - x.min()
#
# ~/anaconda3/envs/endolas/lib/python3.8/site-packages/skimage/restoration/_denoise.py in denoise_bilateral(image, win_size, sigma_color, sigma_spatial, bins, mode, cval, multichannel)
#     203     # so we verify we have a positive image and that the max is not 0.0.
#     204     if min_value < 0.0:
# --> 205         raise ValueError("Image must contain only positive values")
#     206
#     207     if max_value == 0.0:
#
# ValueError: Image must contain only positive values

# %% [markdown]
# ### 2. Linearly Interpolate between neighbors
# First we define a function to linearly interpolate a coding between two existing codings with a factor $\alpha$ in $[0,1]$. Therefore, we define:
# $$ \hat{\mathbf{c}} = (\mathbf{\mu}_2 - \mathbf{\mu}_1)\alpha + \mathbf{\mu}_1$$

# %%
def interpolate_codings(first_coding, second_coding, alpha):
    return (second_coding - first_coding) * alpha + first_coding

# %% [markdown]
# Here we select four ground truth images for which we first compute the coding through the encoder. Then we sample with a factor of $\alpha$, values between the first and the second image and the third and the fourth image. After, we sample again between the previously sampled points to cover approximatley the space between all ground truth images.

# %%
first_image_id = 0
second_image_id = 108
third_image_id = 54
fourth_image_id = 18

first_coding = res_encoder[0][first_image_id]
second_coding = res_encoder[0][second_image_id]
third_coding = res_encoder[0][third_image_id]
fourth_coding = res_encoder[0][fourth_image_id]

alphas = list(np.arange(0.0,1.1,0.2))
size = len(alphas)

first_2_second_codings = np.array([interpolate_codings(first_coding, second_coding, alpha) for alpha in alphas])
third_2_fourth_codings = np.array([interpolate_codings(third_coding, fourth_coding, alpha) for alpha in alphas])

codings = np.zeros((size, size, latent_dim))

for i in range(size):
    first_2_second_coding = first_2_second_codings[i]
    third_2_fourth_coding = third_2_fourth_codings[i]
    
    vertical_codings = np.array([interpolate_codings(first_2_second_coding, third_2_fourth_coding, alpha) for alpha in alphas])
    
    codings[:, i, :] = vertical_codings

codings = codings.reshape((size * size, latent_dim))
res_decoder = decoder.predict(codings)

x_coords = list()
y_coords = list()

for i in range(size * size):
    x, y = postprocess_coordinate_images(res_decoder, i)
    x_coords.append(x)
    y_coords.append(y)

# %% [markdown]
# We can now display the learned manifold:

# %%
plt.rcParams["figure.figsize"] = (40,40)

for i in range(size * size):
    x = x_coords[i]
    y = y_coords[i]
    
    plt.subplot(size, size, i+1)
    plt.imshow(reconstruct_image(x, y),cmap='gist_gray')
    plt.axis('off')
    plt.tight_layout()
    
plt.savefig('weights/vae/learned_manifold_gt.png')

# %% [markdown]
# ## Display manifold
# Using the t-SNE we can reduced our data into a two-dimensional space.

# %%
def postprocess(results, index):
    x = results[index,:,:,0]
    y = results[index,:,:,1]
        
    x_max_orig = x.max()
    y_max_orig = y.max()
    
    # Smooth
    x = denoise_bilateral(x, mode='edge',sigma_spatial=100, win_size=3)
    y = denoise_bilateral(y, mode='edge',sigma_spatial=100, win_size=3)
    
    # Equalize possible offset due to smoothing
    x = x - x.min()
    y = y - y.min()
    
    x = x * (x_max_orig / x.max())
    y = y * (y_max_orig / y.max())
    
    # Sort out irregularities in x
    for i in range(len(x)):        
        max_value=0.0
        for j in range(len(x[i])):
            if x[i][j] <= max_value:
                x[i][j] = 0.0
                y[i][j] = 0.0
            else: 
                max_value = x[i][j]
            
    # Sort out irregularities in y
    for i in range(len(y[0])):        
        max_value=0.0
        for j in reversed(range(len(y))):
            if y[j][i] <= max_value:
                x[j][i] = 0.0
                y[j][i] = 0.0
            else:
                max_value = y[j][i]
    
    return x, y

# %%
linearized_data_x = xy_data[:,:,:,0]
dim_1 = linearized_data_x.shape[0]
dim_2 = linearized_data_x.shape[1] * linearized_data_x.shape[2]

linearized_data_x = linearized_data_x.reshape((dim_1, dim_2))

# %%
res_decoder = decoder.predict(res_encoder[0])

#linearized_decoder_x = np.zeros(linearized_data_x.shape)
#for i in range(len(linearized_decoder_x)):
#    x, y = postprocess(res_decoder, i)
#    linearized_decoder_x[i] = x.flatten()

linearized_decoder_x = res_decoder[:,:,:,0]
dim_1 = linearized_decoder_x.shape[0]
dim_2 = linearized_decoder_x.shape[1] * linearized_decoder_x.shape[2]
linearized_decoder_x = linearized_decoder_x.reshape((dim_1, dim_2))
 
manifold = TSNE(learning_rate=50)
data = np.concatenate((linearized_data_x, linearized_decoder_x), axis=0)
tsne_features = manifold.fit_transform(data)

# %%
plt.rcParams["figure.figsize"] = (10,10)

plt.scatter(tsne_features[0:160, 0], tsne_features[0:160, 1], c='r')
plt.scatter(tsne_features[160:320, 0], tsne_features[160:320, 1], c='b')
