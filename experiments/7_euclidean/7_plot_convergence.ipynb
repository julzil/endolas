# %% [markdown]
# # Import packages

# %%
import sys

# %%
import sys
#sys.path.append("D:\Julian\workspace\endolas")
sys.path.append("/home/julian/Documents/Studium/MT-Masterarbeit/Workspace/endolas")

import numpy as np
import matplotlib.pyplot as plt
import utils
import os
import importlib

# %% [markdown]
# # Load data and plot

# %%
series = 7
experiments = [1,2]
paths = dict()

for experiment in experiments:
    paths[experiment] = os.path.abspath('../{}_{}_euclidean/log'.format(series, experiment))

# %%
importlib.reload(utils)
utils.plot_convergence(paths,
                       series,
                       epochs=100,
                       sigma=1,
                       append='_train_val',
                       ylabel="MSED",
                       plot1=1,
                       plot2=3,
                       log =True)
# Out:
# /home/julian/Documents/Studium/MT-Masterarbeit/Workspace/endolas/utils.py:232: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim([0, 200])
