# %%
import imageio
import numpy as np
import json
from matplotlib import pyplot as plt
from skimage.transform import warp
from scipy.ndimage import gaussian_filter
from scipy import ndimage
from pdb import set_trace

import glob
import math
import nibabel as nib
from endolas import utils
import random
import os
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
base_dir = '/home/julian/Documents/Studium/MT-Masterarbeit/Data/LASTEN2A'

width = 768
height = 768

n_x = 18
n_y = 18

sample_size = 2160
#sample_size = 10

start_sample = 240
end_sample = start_sample + sample_size

p_dropout = 0.7
p_sinus = 0.7
p_rot = 0.7
p_scale = 0.7
p_shear = 0.7
p_global_trans = 0.7
p_local_trans = 0.7

# -----------
dropout_max = 0.2

x_sin_max = 0.15 * height
y_sin_max = 0.015 * width

rot_max = math.pi * 0.1125 # 22.5 deg

x_scale_max = 1.25
y_scale_max = 1.25

x_shear_max = math.pi * 0.05625 # 11.25 deg
y_shear_max = math.pi * 0.05625 # 11.25 deg

x_global_max = 0.2 * width
y_global_max = 0.2 * height

x_local_max = 0.005 * width
y_local_max = 0.005 * height

# %%
spacing_x = (width / 2.0) / n_x
spacing_y = (height / 2.0) / n_y

base_offset_x = width / 4.0
base_offset_y = height / 4.0

offset_x = spacing_x / 2.0 + base_offset_x
offset_y = spacing_y / 2.0 + base_offset_y

# %%
def random_decision(probability):
    return random.random() < probability

# %%
def apply_sinus(x, y, rand_1, rand_2): 
    y_ratio = (y - offset_y) / (spacing_y * (n_y - 1))
    y_sin = math.sin(y_ratio * math.pi) * y_sin_max * rand_1
    u = x - round(y_sin)
    
    x_ratio = (x - offset_x) / (spacing_x * (n_x - 1))
    x_sin = math.sin(x_ratio * math.pi) * x_sin_max * rand_2
    v = y - round(x_sin)
    
    return u,v

def apply_rot(x, y, rand_1):
    shift_x = round(width / 2)
    shift_y = round(height / 2)
    
    x = x - shift_x
    y = y - shift_y
    
    alpha = rot_max * rand_1
    
    vec = np.array([x, y])
    mat = np.array([[np.cos(alpha), -np.sin(alpha)],
                    [np.sin(alpha), np.cos(alpha)]])

    vec = np.dot(mat, vec)
    
    u = int(round(vec[0]))
    v = int(round(vec[1]))
    
    u = u + shift_x
    v = v + shift_y
    
    return u,v

def apply_scale(x, y, rand_1, rand_2):
    rand_1 = (rand_1 + 1.0) / 2.0
    rand_2 = (rand_1 + 1.0) / 2.0
    
    shift_x = round(width / 2)
    shift_y = round(height / 2)
    
    x = x - shift_x
    y = y - shift_y
    
    x_scale = (1 / x_scale_max) + (x_scale_max - (1 / x_scale_max)) * rand_1
    y_scale = (1 / y_scale_max) + (y_scale_max - (1 / y_scale_max)) * rand_2
    
    vec = np.array([x, y])
    mat = np.array([[x_scale, 0      ],
                    [0      , y_scale]])

    vec = np.dot(mat, vec)
    
    u = int(round(vec[0]))
    v = int(round(vec[1]))
    
    u = u + shift_x
    v = v + shift_y
    
    return u,v

def apply_shear(x, y, rand_1, rand_2):
    shift_x = round(width / 2)
    shift_y = round(height / 2)
    
    x = x - shift_x
    y = y - shift_y
    
    phi = x_shear_max * rand_1
    psi = y_shear_max * rand_2
    
    vec = np.array([x, y])
    mat = np.array([[1          , np.tan(phi)],
                    [np.tan(psi), 1          ]])

    vec = np.dot(mat, vec)
    
    u = int(round(vec[0]))
    v = int(round(vec[1]))
    
    u = u + shift_x
    v = v + shift_y
    
    return u,v

def apply_global_trans(x, y, rand_1, rand_2):
    u = x + round(x_global_max * rand_1)
    v = y + round(y_global_max * rand_2)
    
    return u,v

def apply_local_trans(x, y):
    u = x + round(x_local_max * (random.random() * 2.0 - 1.0))
    v = y + round(y_local_max * (random.random() * 2.0 - 1.0))
    
    return u,v

def apply_dropout(rand):
    dropout = dropout_max * rand
    if random_decision(dropout):
        return True
        
    else:
        return False

# %%
def get_fixed_data(sample_index):
    is_dropout = random_decision(p_dropout)
    
    fixed = np.zeros((height, width))
    index_2_xy = dict()
    index = 0
    rand = random.random()
    for index_y in reversed(range(n_y)):
        y = int(round(offset_y + (spacing_y * index_y)))

        for index_x in range(n_x):
            x = int(round(offset_x + (spacing_x * index_x)))
            
            drop = apply_dropout(rand) if (is_dropout and sample_index!=0) else False
            
            if not drop:
                fixed[y][x] = 1
                index_2_xy[index] = (x, y)
            
            index += 1
            
    return fixed, index_2_xy

# %%
def get_moving_data(rand_1, rand_2, sample_index, index_2_xy):
    is_dropout = random_decision(p_dropout)
    is_sinus = random_decision(p_sinus)
    is_rot = random_decision(p_rot)
    is_scale = random_decision(p_scale)
    is_shear = random_decision(p_shear)
    is_global_trans = random_decision(p_global_trans)
    is_local_trans = random_decision(p_local_trans)
    
    moving = np.zeros((height, width))
    index_2_uv = dict()
    
    rand = random.random()
    
    for index, xy in index_2_xy.items():
        x=xy[0]
        y=xy[1]
            
        drop = apply_dropout(rand) if is_dropout else False
          
        if not drop:
            u = x
            v = y

            #if sample_index != 0:
            if is_sinus: u,v = apply_sinus(u, v, rand_1, rand_2)
            if is_rot: u,v = apply_rot(u, v, rand_1) 
            if is_scale: u,v = apply_scale(u, v, rand_1, rand_2) 
            if is_shear: u,v = apply_shear(u, v, rand_1, rand_2) 
            if is_global_trans: u,v = apply_global_trans(u, v, rand_1, rand_2) 
            if is_local_trans: u,v = apply_local_trans(u, v) 

            if u < 0 or v < 0 or u > (width-1) or v > (height-1):
                print('Additional attempt for sample index "{}"'.format(sample_index))
                return None, None, False

            else:
                moving[v][u] = 1
                index_2_uv[index] = (u, v)
            
    return moving, index_2_uv, True

# %%
for set_type in ["train"]:
    print("Start {}".format(set_type))
    load_dir = base_dir + os.sep + set_type + os.sep
    save_dir = base_dir + os.sep + "aug" + os.sep

    globs = glob.glob(load_dir + "*.json")
    globs = [int(path.split(os.sep)[-1].split(".")[0]) for path in globs]
    image_ids = sorted(globs)
    
    global_index = 10000

    for image_id in image_ids:
        store_dir = save_dir + "{}".format(image_id) + os.sep
        
        sample_path = load_dir + "{}.json".format(image_id)
        with open(sample_path) as sample_file:
            sample_json_o = json.load(sample_file)
            sample_json = dict()

            for key, value in sample_json_o.items():
                sample_json[int(key)] = value

        for _ in range(0,19):
            index_2_xy = sample_json

            is_valid = False
            while(not is_valid):
                rand_1 = random.random() * 2.0 - 1.0
                rand_2 = random.random() * 2.0 - 1.0

                moving, index_2_uv, is_valid = get_moving_data(rand_1, rand_2, global_index, index_2_xy)

            json_file = json.dumps(index_2_uv)
            f = open(store_dir + "{}.json".format(global_index), "w")
            f.write(json_file)
            f.close()

            moving = utils.apply_smoothing(moving, sigma=2, sigma_back=15)
            plt.imsave(store_dir + "{}_mov.png".format(global_index), moving, cmap="gray")
            
            global_index += 1
# Out:
# Start train
# Additional attempt for sample index "10007"
# Additional attempt for sample index "10020"
# Additional attempt for sample index "10036"
# Additional attempt for sample index "10038"
# Additional attempt for sample index "10042"
# Additional attempt for sample index "10065"
# Additional attempt for sample index "10067"
# Additional attempt for sample index "10067"
# Additional attempt for sample index "10073"
# Additional attempt for sample index "10073"
# Additional attempt for sample index "10077"
# Additional attempt for sample index "10105"
# Additional attempt for sample index "10112"
# Additional attempt for sample index "10112"
# Additional attempt for sample index "10125"
# Additional attempt for sample index "10126"
# Additional attempt for sample index "10127"
# Additional attempt for sample index "10154"
# Additional attempt for sample index "10166"
# Additional attempt for sample index "10169"
# Additional attempt for sample index "10181"
# Additional attempt for sample index "10200"
# Additional attempt for sample index "10215"
# Additional attempt for sample index "10227"
# Additional attempt for sample index "10258"
# Additional attempt for sample index "10264"
# Additional attempt for sample index "10281"
# Additional attempt for sample index "10292"
# Additional attempt for sample index "10296"
# Additional attempt for sample index "10296"
# Additional attempt for sample index "10296"
# Additional attempt for sample index "10333"
# Additional attempt for sample index "10337"
# Additional attempt for sample index "10342"
# Additional attempt for sample index "10352"
# Additional attempt for sample index "10383"
# Additional attempt for sample index "10383"
# Additional attempt for sample index "10383"
# Additional attempt for sample index "10387"
# Additional attempt for sample index "10390"
# Additional attempt for sample index "10406"
# Additional attempt for sample index "10407"
# Additional attempt for sample index "10435"
# Additional attempt for sample index "10436"
# Additional attempt for sample index "10481"
# Additional attempt for sample index "10484"
# Additional attempt for sample index "10490"
# Additional attempt for sample index "10496"
# Additional attempt for sample index "10501"
# Additional attempt for sample index "10507"
# Additional attempt for sample index "10541"
# Additional attempt for sample index "10560"
# Additional attempt for sample index "10571"
# Additional attempt for sample index "10576"
# Additional attempt for sample index "10589"
# Additional attempt for sample index "10597"
# Additional attempt for sample index "10622"
# Additional attempt for sample index "10625"
# Additional attempt for sample index "10642"
# Additional attempt for sample index "10644"
# Additional attempt for sample index "10684"
# Additional attempt for sample index "10695"
# Additional attempt for sample index "10711"
# Additional attempt for sample index "10714"
# Additional attempt for sample index "10756"
# Additional attempt for sample index "10764"
# Additional attempt for sample index "12128"
# Additional attempt for sample index "12136"
# Additional attempt for sample index "12136"
# Additional attempt for sample index "12136"
# Additional attempt for sample index "12146"
# Additional attempt for sample index "12148"
# Additional attempt for sample index "12151"
# Additional attempt for sample index "12153"
# Additional attempt for sample index "12153"
# Additional attempt for sample index "12156"
# Additional attempt for sample index "12159"
# Additional attempt for sample index "12160"
# Additional attempt for sample index "12171"
# Additional attempt for sample index "12171"
# Additional attempt for sample index "12178"
# Additional attempt for sample index "12184"
# Additional attempt for sample index "12186"
# Additional attempt for sample index "12189"
# Additional attempt for sample index "12191"
# Additional attempt for sample index "12201"
# Additional attempt for sample index "12207"
# Additional attempt for sample index "12208"
# Additional attempt for sample index "12214"
# Additional attempt for sample index "12214"
# Additional attempt for sample index "12219"
# Additional attempt for sample index "12227"
# Additional attempt for sample index "12230"
# Additional attempt for sample index "12237"
# Additional attempt for sample index "12242"
# Additional attempt for sample index "12245"
# Additional attempt for sample index "12251"
# Additional attempt for sample index "12254"
# Additional attempt for sample index "12254"
# Additional attempt for sample index "12258"
# Additional attempt for sample index "12260"
# Additional attempt for sample index "12269"
# Additional attempt for sample index "12269"
# Additional attempt for sample index "12279"
# Additional attempt for sample index "12283"
# Additional attempt for sample index "12283"
# Additional attempt for sample index "12287"
# Additional attempt for sample index "12288"
# Additional attempt for sample index "12288"
# Additional attempt for sample index "12289"
# Additional attempt for sample index "12294"
# Additional attempt for sample index "12296"
# Additional attempt for sample index "12304"
# Additional attempt for sample index "12309"
# Additional attempt for sample index "12313"
# Additional attempt for sample index "12316"
# Additional attempt for sample index "12316"
# Additional attempt for sample index "12316"
# Additional attempt for sample index "12317"
# Additional attempt for sample index "12317"
# Additional attempt for sample index "12322"
# Additional attempt for sample index "12326"
# Additional attempt for sample index "12327"
# Additional attempt for sample index "12329"
# Additional attempt for sample index "12332"
# Additional attempt for sample index "12332"
# Additional attempt for sample index "12337"
# Additional attempt for sample index "12339"
# Additional attempt for sample index "12340"
# Additional attempt for sample index "12342"
# Additional attempt for sample index "12347"
# Additional attempt for sample index "12347"
# Additional attempt for sample index "12350"
# Additional attempt for sample index "12351"
# Additional attempt for sample index "12351"
# Additional attempt for sample index "12361"
# Additional attempt for sample index "12364"
# Additional attempt for sample index "12368"
# Additional attempt for sample index "12373"
# Additional attempt for sample index "12373"
# Additional attempt for sample index "12374"
# Additional attempt for sample index "12377"
# Additional attempt for sample index "12378"
# Additional attempt for sample index "12384"
# Additional attempt for sample index "12384"
# Additional attempt for sample index "12385"
# Additional attempt for sample index "12386"
# Additional attempt for sample index "12388"
# Additional attempt for sample index "12395"
# Additional attempt for sample index "12396"
# Additional attempt for sample index "12399"
# Additional attempt for sample index "12399"
# Additional attempt for sample index "12412"
# Additional attempt for sample index "12415"
# Additional attempt for sample index "12419"
# Additional attempt for sample index "12423"
# Additional attempt for sample index "12432"
# Additional attempt for sample index "12434"
# Additional attempt for sample index "12435"
# Additional attempt for sample index "12437"
# Additional attempt for sample index "12441"
# Additional attempt for sample index "12443"
# Additional attempt for sample index "12443"
# Additional attempt for sample index "12444"
# Additional attempt for sample index "12445"
# Additional attempt for sample index "12446"
# Additional attempt for sample index "12453"
# Additional attempt for sample index "12457"
# Additional attempt for sample index "12457"
# Additional attempt for sample index "12458"
# Additional attempt for sample index "12463"
# Additional attempt for sample index "12464"
# Additional attempt for sample index "12468"
# Additional attempt for sample index "12468"
# Additional attempt for sample index "12477"
# Additional attempt for sample index "12477"
# Additional attempt for sample index "12478"
# Additional attempt for sample index "12478"
# Additional attempt for sample index "12478"
# Additional attempt for sample index "12484"
# Additional attempt for sample index "12484"
# Additional attempt for sample index "12484"
# Additional attempt for sample index "12487"
# Additional attempt for sample index "12487"
# Additional attempt for sample index "12487"
# Additional attempt for sample index "12487"
# Additional attempt for sample index "12494"
# Additional attempt for sample index "12494"
# Additional attempt for sample index "12495"
# Additional attempt for sample index "12495"
# Additional attempt for sample index "12495"
# Additional attempt for sample index "12502"
# Additional attempt for sample index "12511"
# Additional attempt for sample index "12514"
# Additional attempt for sample index "12514"
# Additional attempt for sample index "12514"
# Additional attempt for sample index "12514"
# Additional attempt for sample index "12518"
# Additional attempt for sample index "12523"
# Additional attempt for sample index "12531"
# Additional attempt for sample index "12542"
# Additional attempt for sample index "12544"
# Additional attempt for sample index "12547"
# Additional attempt for sample index "12548"
# Additional attempt for sample index "12549"
# Additional attempt for sample index "12555"
# Additional attempt for sample index "12556"
# Additional attempt for sample index "12562"
# Additional attempt for sample index "12564"
# Additional attempt for sample index "12566"
# Additional attempt for sample index "12567"
# Additional attempt for sample index "12574"
# Additional attempt for sample index "12581"
# Additional attempt for sample index "12582"
# Additional attempt for sample index "12582"
# Additional attempt for sample index "12588"
# Additional attempt for sample index "12590"
# Additional attempt for sample index "12594"
# Additional attempt for sample index "12598"
# Additional attempt for sample index "12599"
# Additional attempt for sample index "12617"
# Additional attempt for sample index "12632"
# Additional attempt for sample index "12633"
# Additional attempt for sample index "12635"
# Additional attempt for sample index "12637"
# Additional attempt for sample index "12637"
# Additional attempt for sample index "12643"
# Additional attempt for sample index "12648"
# Additional attempt for sample index "12650"
# Additional attempt for sample index "12656"
# Additional attempt for sample index "12657"
# Additional attempt for sample index "12666"
# Additional attempt for sample index "12678"
# Additional attempt for sample index "12739"
# Additional attempt for sample index "12739"
# Additional attempt for sample index "12765"
# Additional attempt for sample index "12837"
# Additional attempt for sample index "12864"
# Additional attempt for sample index "12908"
# Additional attempt for sample index "12908"
# Additional attempt for sample index "12914"
# Additional attempt for sample index "13003"
# Additional attempt for sample index "13022"
# Additional attempt for sample index "13025"

# %%
globs = glob.glob(load_dir + "*.json")
globs = [int(path.split(os.sep)[-1].split(".")[0]) for path in globs]
image_ids = sorted(globs)
