# %% [markdown]
# # Import packages

# %%
import sys
sys.path.append("D:\Julian\workspace\endolas")

import numpy as np
import matplotlib.pyplot as plt
import utils
import os
import importlib

# %% [markdown]
# # Load data and plot

# %%
experiments = [1,2,3,4]
paths = dict()

for experiment in experiments:
    paths[experiment] = os.path.abspath('../2_{}_segmentation/result.log'.format(experiment))

# %%
importlib.reload(utils)
utils.plot_convergence(paths, epochs=100, sigma=-1, normalize=False, label="IoU", plot=-2)
