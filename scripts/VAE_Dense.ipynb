# %% [markdown]
# # Variational Autoencoder for Augmentation of Laser-Based Laryngeal Imaging
#
# For the deep-learning-based algorithm to match features via a registration task, it is essential to have apply intense data augmentation to the training data set. As displayed in the following figure the training data consists of images $m(x)$ that represent the spatial configuration of laser points projected onto the vocal fold surface.
#
# ![alt text here](images/feature_matching_registration.png "Logo Title Jupyter Notebook logo")
#
# The foundation for the images $m(x)$ are the x-y-coordinates of each single laser point within the image, as $m(x)$ is generated by plotting the single laser points and then smoothing the image. To create intense augmentation we want to train a variational autoencoder (VAE) to then generate images that are variations of the images of the training set and represent feasible configurations of laser points projected onto a vocal fold. The implementation of the VAE is inspired by [Keras](https://keras.io/examples/generative/vae/).
#
# In a VAE a decoder-encoder architecture is utilized. The coding is split up into a vector representing the mean $\mu$
# of a distribution over a latent space. The distribution is assumed to be gaussian. Therefore, a second vector exists as a coding representing the variance $\mathbf{\sigma^2}$. Behind the coding a sampling layer exists that randomly samples a value from the distribution given by $\mathcal{N}(\mu,\,\sigma^{2})$. Like that it is possible to create a smooth latent space. The network can be trained in a unsupervised manner, as the the decoder should learn to reconstruct the input of the encoder as good as possible. After training, only the decoder part will be used. Inputing random points in the latent space will then generate x- and y-coordinates that are part of the underlying trained distribution based on the ground truth.

# %% [markdown]
# ## Imports
# The notebook was developed on Keras using the Tensorflow 2.2.0 backend.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
from scipy.ndimage import gaussian_filter

# %% [markdown]
# ## Hardware Configuration
# Check for GPU and allow memory growth such that limitations for training are reduced.

# %%
if len(tf.config.experimental.get_visible_devices('GPU')):
    physical_devices = tf.config.experimental.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Functionality
# The following functionality helps to create the images for training the registration task.

# %%
def apply_smoothing(image, sigma=1.0, sigma_back=10.0):
    image_orig = image
    image = gaussian_filter(image, sigma=sigma)
    image_back = gaussian_filter(image, sigma=sigma_back)

    image = (image / image.max()) * 255
    image_back = (image_back / image_back.max()) * 255
    image = 0.3 * image_orig + 0.3 * image + 0.3 * image_back

    return image

# %%
def reconstruct_image(x_position, y_position):
    # Unpad
    x_position = x_position[1:-1, 1:-1]
    y_position = y_position[1:-1, 1:-1]
    image = np.zeros((image_height, image_width))
    for x, y in zip(x_position.flatten(), y_position.flatten()):
        x = int(x*image_width)
        y = int(y*image_height)
        
        if x >= 50 and y>= 50:
            image[y][x] = 1
        
    image = apply_smoothing(image, sigma=2, sigma_back=15)
    return image

# %% [markdown]
# ## Model parameters
# The grid dimensions have to be know, as well as the image dimensions for scaling. The amount of input and output layers is 2 here, as we will have one channel representing x-coordinates and a second channel representing y-coordinates.

# %%
grid_width = 18
grid_height = 18

image_width = 728
image_height = 728

inout_layers = 2

# %% [markdown]
# ## Hyperparameters
# The dimension of the latent space can be adapted to optimize the network.

# %%
latent_dim = 8
epochs = 100
batch_size = 10
coding_loss_factor = 1.0
epsilon_factor = 1.0

dense_units = 100

# %% [markdown]
# ## Sampling Layer
# In the sampling layer the coding $\mathbf{\mu}$ and $\log{(\mathbf{\sigma^2})}$ are used to randomly sample a point from the underlying distribution. Due to this randomness that occurs within each batch and along all epochs the decoder is trained on smooth distributions. Each coding $\mathbf{c}$ used to train the decoder is computed as
#
# $$\mathbf{c} = \mathbf{\mu} + e^{0.5\mathbf{\log{(\mathbf{\sigma^2})}}}\mathbf{\epsilon}f$$
#
# where $\epsilon$ is a random vector with entries between 0 and 1 and $f$ is a hyperparameter to control the amount of randomness.

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon * epsilon_factor

# %% [markdown]
# ## Encoder Model
# In the encoder strided convolutional layers are applied to reduce the dimensionality of the input. For a grid with dimension 18x18 the input shape is increased to 20x20 and the input images are padded. Like that it is easier to ensure symmetry between encoder an decoder. The encoder is a keras model having the mean, variance and a sampled value as output.

# %%
encoder_inputs = keras.Input(shape=(grid_width+2, grid_height+2, inout_layers))
x = layers.Flatten()(encoder_inputs)
x = layers.Dense(dense_units, activation="elu")(x)
x = layers.Dense(dense_units, activation="elu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 20, 20, 2)]  0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 800)          0           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          80100       flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       dense[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 8)            808         dense_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 8)            808         dense_1[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 8)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 91,816
# Trainable params: 91,816
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Decoder Model
# The decoder takes only a sampeled value or a randomly selected value with the size of the latent space as input.
# Dimnesion of the input of the encoder is the reconstructed. The decoder is constructed as a keras model.

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(dense_units, activation="elu")(latent_inputs)
x = layers.Dense(dense_units, activation="elu")(x)
x = layers.Dense((grid_height+2)*(grid_width+2)*inout_layers, activation="sigmoid")(x)
decoder_outputs = layers.Reshape((grid_height+2, grid_width+2, inout_layers))(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               900
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 800)               80800
# _________________________________________________________________
# reshape (Reshape)            (None, 20, 20, 2)         0
# =================================================================
# Total params: 91,800
# Trainable params: 91,800
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## VAE Model
# The VAE is composed by the encoder and decoder. The decoder only takes the random coding $\mathbf{c}$ from the encoder. However, the codings $\mathbf{\mu}$ and $\log{(\mathbf{\sigma^2})}$ are used to compute a loss for regularizing and ensuring a smooth overall distribution. The coding loss is:
#
# $$ \epsilon_{coding} = 1 + \log{(\sigma^2)} - \mu^2 - \sigma^2 $$
#
# A binary crossentropy is used to define a reconstruction loss $\epsilon_{reconstruction}$.
# We are doing a regression here, based on probabilities. Therefore, cross entropy needs to be applied. See
# [Explanation](
# https://stats.stackexchange.com/questions/223256/does-the-cross-entropy-cost-make-sense-in-the-context-of-regression). The overall loss is then:
#
# $$\epsilon = \epsilon_{reconstruction} - \epsilon_{coding}$$

# %%
class VariationalAutoEncoder(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VariationalAutoEncoder, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
            
        # Gradient tape allows to "record" a function that will be derived
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = encoder(data)
            
            # Reconstuction Loss
            reconstruction = decoder(z)
            reconstruction_loss = tf.reduce_mean(
                keras.losses.binary_crossentropy(data, reconstruction)
            )
            reconstruction_loss *= grid_height+2 * grid_height+2
            
            # Regularization Loss for well formed latent space and no overfitting
            coding_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            coding_loss = tf.reduce_mean(coding_loss)
            coding_loss *= -(0.2 * coding_loss_factor)
            
            # Total Loss
            total_loss = reconstruction_loss + coding_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "coding_loss": coding_loss,
        }

# %% [markdown]
# ## Prepare data
# Load the data and scale them to be between 0.0 an 1.0. Further use zero-padding to get a 20x20 shape for this example.

# %%
x_position = np.load('data/x_pos_LASTEN2A.npy')
y_position = np.load('data/y_pos_LASTEN2A.npy')

offset = 0.0

# Non existing points mapping
x_position = np.where(x_position<=0, -offset, x_position) + offset
y_position = np.where(x_position<=0, -offset, y_position) + offset

x_position = x_position / (image_width + offset)
y_position = y_position / (image_height + offset)

# Zero padding
x_position = np.pad(x_position,[(0,0),(1,1),(1,1)],constant_values=0)
y_position = np.pad(y_position,[(0,0),(1,1),(1,1)],constant_values=0)

x_position = x_position[:,:,:,np.newaxis]
y_position = y_position[:,:,:,np.newaxis]

xy_data = np.concatenate((x_position, y_position), axis=3)
print("Shape of 'xy_data': {}".format(xy_data.shape))
# Out:
# Shape of 'xy_data': (3200, 20, 20, 2)

# %%
x_position[0,:,:,0].max()
# Out:
# 0.7637362637362637

# %% [markdown]
# ## Training
# Initialize the VAE, compile it and fit the model.

# %%
vae = VariationalAutoEncoder(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
history = vae.fit(xy_data, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 320/320 [==============================] - 1s 3ms/step - loss: 29.1724 - reconstruction_loss: 28.8641 - coding_loss: 0.3084
# Epoch 2/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.9874 - reconstruction_loss: 27.6941 - coding_loss: 0.2934
# Epoch 3/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.7338 - reconstruction_loss: 27.4526 - coding_loss: 0.2813
# Epoch 4/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.5323 - reconstruction_loss: 27.2627 - coding_loss: 0.2695
# Epoch 5/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.4424 - reconstruction_loss: 27.1676 - coding_loss: 0.2747
# Epoch 6/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.3890 - reconstruction_loss: 27.1127 - coding_loss: 0.2763
# Epoch 7/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.3726 - reconstruction_loss: 27.0910 - coding_loss: 0.2816
# Epoch 8/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.3520 - reconstruction_loss: 27.0736 - coding_loss: 0.2784
# Epoch 9/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.3288 - reconstruction_loss: 27.0541 - coding_loss: 0.2747
# Epoch 10/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.3174 - reconstruction_loss: 27.0405 - coding_loss: 0.2769
# Epoch 11/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.3070 - reconstruction_loss: 27.0313 - coding_loss: 0.2758
# Epoch 12/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2957 - reconstruction_loss: 27.0212 - coding_loss: 0.2745
# Epoch 13/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2905 - reconstruction_loss: 27.0175 - coding_loss: 0.2730
# Epoch 14/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2893 - reconstruction_loss: 27.0107 - coding_loss: 0.2787
# Epoch 15/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2847 - reconstruction_loss: 27.0057 - coding_loss: 0.2789
# Epoch 16/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2771 - reconstruction_loss: 27.0003 - coding_loss: 0.2768
# Epoch 17/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2686 - reconstruction_loss: 26.9890 - coding_loss: 0.2796
# Epoch 18/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2594 - reconstruction_loss: 26.9815 - coding_loss: 0.2779
# Epoch 19/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2628 - reconstruction_loss: 26.9851 - coding_loss: 0.2777
# Epoch 20/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2491 - reconstruction_loss: 26.9726 - coding_loss: 0.2764
# Epoch 21/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2524 - reconstruction_loss: 26.9713 - coding_loss: 0.2811
# Epoch 22/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2437 - reconstruction_loss: 26.9618 - coding_loss: 0.2819
# Epoch 23/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2408 - reconstruction_loss: 26.9609 - coding_loss: 0.2799
# Epoch 24/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2388 - reconstruction_loss: 26.9588 - coding_loss: 0.2800
# Epoch 25/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2361 - reconstruction_loss: 26.9530 - coding_loss: 0.2830
# Epoch 26/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2322 - reconstruction_loss: 26.9528 - coding_loss: 0.2794
# Epoch 27/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2312 - reconstruction_loss: 26.9505 - coding_loss: 0.2806
# Epoch 28/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2248 - reconstruction_loss: 26.9447 - coding_loss: 0.2800
# Epoch 29/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2266 - reconstruction_loss: 26.9465 - coding_loss: 0.2801
# Epoch 30/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2209 - reconstruction_loss: 26.9399 - coding_loss: 0.2810
# Epoch 31/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2258 - reconstruction_loss: 26.9448 - coding_loss: 0.2810
# Epoch 32/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2127 - reconstruction_loss: 26.9327 - coding_loss: 0.2800
# Epoch 33/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2172 - reconstruction_loss: 26.9352 - coding_loss: 0.2820
# Epoch 34/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2110 - reconstruction_loss: 26.9301 - coding_loss: 0.2809
# Epoch 35/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2136 - reconstruction_loss: 26.9336 - coding_loss: 0.2800
# Epoch 36/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2120 - reconstruction_loss: 26.9319 - coding_loss: 0.2802
# Epoch 37/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2110 - reconstruction_loss: 26.9305 - coding_loss: 0.2805
# Epoch 38/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2042 - reconstruction_loss: 26.9229 - coding_loss: 0.2813
# Epoch 39/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2143 - reconstruction_loss: 26.9301 - coding_loss: 0.2842
# Epoch 40/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2012 - reconstruction_loss: 26.9225 - coding_loss: 0.2787
# Epoch 41/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2049 - reconstruction_loss: 26.9257 - coding_loss: 0.2792
# Epoch 42/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2074 - reconstruction_loss: 26.9253 - coding_loss: 0.2820
# Epoch 43/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2005 - reconstruction_loss: 26.9223 - coding_loss: 0.2782
# Epoch 44/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2027 - reconstruction_loss: 26.9234 - coding_loss: 0.2793
# Epoch 45/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2036 - reconstruction_loss: 26.9189 - coding_loss: 0.2847
# Epoch 46/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2003 - reconstruction_loss: 26.9177 - coding_loss: 0.2827
# Epoch 47/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1923 - reconstruction_loss: 26.9137 - coding_loss: 0.2786
# Epoch 48/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.2012 - reconstruction_loss: 26.9169 - coding_loss: 0.2844
# Epoch 49/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1935 - reconstruction_loss: 26.9108 - coding_loss: 0.2827
# Epoch 50/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1907 - reconstruction_loss: 26.9127 - coding_loss: 0.2779
# Epoch 51/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1904 - reconstruction_loss: 26.9052 - coding_loss: 0.2852
# Epoch 52/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1914 - reconstruction_loss: 26.9077 - coding_loss: 0.2838
# Epoch 53/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1891 - reconstruction_loss: 26.9065 - coding_loss: 0.2827
# Epoch 54/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1884 - reconstruction_loss: 26.9079 - coding_loss: 0.2805
# Epoch 55/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1856 - reconstruction_loss: 26.9021 - coding_loss: 0.2835
# Epoch 56/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1898 - reconstruction_loss: 26.9062 - coding_loss: 0.2836
# Epoch 57/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1823 - reconstruction_loss: 26.9041 - coding_loss: 0.2782
# Epoch 58/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1781 - reconstruction_loss: 26.8993 - coding_loss: 0.2789
# Epoch 59/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1837 - reconstruction_loss: 26.9026 - coding_loss: 0.2812
# Epoch 60/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1860 - reconstruction_loss: 26.9039 - coding_loss: 0.2822
# Epoch 61/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1827 - reconstruction_loss: 26.9007 - coding_loss: 0.2820
# Epoch 62/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1767 - reconstruction_loss: 26.8932 - coding_loss: 0.2835
# Epoch 63/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1801 - reconstruction_loss: 26.8941 - coding_loss: 0.2860
# Epoch 64/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1832 - reconstruction_loss: 26.8997 - coding_loss: 0.2836
# Epoch 65/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1803 - reconstruction_loss: 26.9004 - coding_loss: 0.2799
# Epoch 66/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1793 - reconstruction_loss: 26.8930 - coding_loss: 0.2863
# Epoch 67/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1713 - reconstruction_loss: 26.8907 - coding_loss: 0.2807
# Epoch 68/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1756 - reconstruction_loss: 26.8934 - coding_loss: 0.2822
# Epoch 69/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1759 - reconstruction_loss: 26.8924 - coding_loss: 0.2835
# Epoch 70/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1747 - reconstruction_loss: 26.8927 - coding_loss: 0.2820
# Epoch 71/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1799 - reconstruction_loss: 26.8928 - coding_loss: 0.2871
# Epoch 72/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1749 - reconstruction_loss: 26.8930 - coding_loss: 0.2819
# Epoch 73/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1748 - reconstruction_loss: 26.8881 - coding_loss: 0.2867
# Epoch 74/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1656 - reconstruction_loss: 26.8857 - coding_loss: 0.2799
# Epoch 75/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1766 - reconstruction_loss: 26.8906 - coding_loss: 0.2860
# Epoch 76/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1740 - reconstruction_loss: 26.8905 - coding_loss: 0.2835
# Epoch 77/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1714 - reconstruction_loss: 26.8870 - coding_loss: 0.2844
# Epoch 78/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1734 - reconstruction_loss: 26.8877 - coding_loss: 0.2857
# Epoch 79/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1646 - reconstruction_loss: 26.8834 - coding_loss: 0.2812
# Epoch 80/100
# 320/320 [==============================] - 1s 4ms/step - loss: 27.1681 - reconstruction_loss: 26.8820 - coding_loss: 0.2861
# Epoch 81/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1718 - reconstruction_loss: 26.8873 - coding_loss: 0.2845
# Epoch 82/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1753 - reconstruction_loss: 26.8870 - coding_loss: 0.2884
# Epoch 83/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1686 - reconstruction_loss: 26.8816 - coding_loss: 0.2870
# Epoch 84/100
# 320/320 [==============================] - 1s 4ms/step - loss: 27.1713 - reconstruction_loss: 26.8833 - coding_loss: 0.2880
# Epoch 85/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1695 - reconstruction_loss: 26.8838 - coding_loss: 0.2857
# Epoch 86/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1675 - reconstruction_loss: 26.8820 - coding_loss: 0.2855
# Epoch 87/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1635 - reconstruction_loss: 26.8814 - coding_loss: 0.2821
# Epoch 88/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1655 - reconstruction_loss: 26.8806 - coding_loss: 0.2849
# Epoch 89/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1681 - reconstruction_loss: 26.8812 - coding_loss: 0.2869
# Epoch 90/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1616 - reconstruction_loss: 26.8789 - coding_loss: 0.2827
# Epoch 91/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1699 - reconstruction_loss: 26.8790 - coding_loss: 0.2909
# Epoch 92/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1610 - reconstruction_loss: 26.8812 - coding_loss: 0.2799
# Epoch 93/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1657 - reconstruction_loss: 26.8768 - coding_loss: 0.2889
# Epoch 94/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1594 - reconstruction_loss: 26.8776 - coding_loss: 0.2818
# Epoch 95/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1593 - reconstruction_loss: 26.8766 - coding_loss: 0.2827
# Epoch 96/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1672 - reconstruction_loss: 26.8797 - coding_loss: 0.2875
# Epoch 97/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1653 - reconstruction_loss: 26.8768 - coding_loss: 0.2884
# Epoch 98/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1611 - reconstruction_loss: 26.8782 - coding_loss: 0.2830
# Epoch 99/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1623 - reconstruction_loss: 26.8779 - coding_loss: 0.2843
# Epoch 100/100
# 320/320 [==============================] - 1s 3ms/step - loss: 27.1582 - reconstruction_loss: 26.8753 - coding_loss: 0.2829

# %%
print('Mean reconstruction loss over last 20 epochs: {}'.format(np.array(history.history['reconstruction_loss'][-20:]).mean()))
# Out:
# Mean reconstruction loss over last 20 epochs: 27.186742877960206

# %%
print('Mean coding loss over last 20 epochs: {}'.format(np.array(history.history['coding_loss'][-20:]).mean()))
# Out:
# Mean coding loss over last 20 epochs: 0.27253064811229705

# %%
plt.semilogy(history.history['reconstruction_loss'], label='Reconstruction Loss')
plt.title('Crossentropy Loss for Reconstruction of Input images')
plt.ylabel('Crossentropy')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Predict images and compare with ground truth
# Get the mean value for a ground truth image and decode the value to reconstruct the image

# %%
res_encoder = encoder.predict(xy_data)[0]
res_decoder = decoder.predict(res_encoder)
plt.rcParams["figure.figsize"] = (20,20)

# %% [markdown]
# ### Predicition of x-coordinates by autoencoder
# Out of all 8 recordings from the dataset one frame is displayed

# %%
for i in range(8):
    val = 441 + i
    plt.subplot(val)
    x = res_decoder[i*20,:,:,0]
    plt.imshow(x)
    plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# ### Ground-truth of x-coordinates
# Out of all 8 recordings from the dataset one frame is displayed

# %%
for i in range(8):
    val = 441 + i
    plt.subplot(val)
    x = xy_data[i*20,:,:,0]
    plt.imshow(x)
    plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# ### Predicition of x-y-coordinates and display in image space
# Out of all 8 recordings from the dataset one frame is displayed

# %%
for i in range(8):
    val = 441 + i
    plt.subplot(val)
    x = res_decoder[i*20,:,:,0]
    y = res_decoder[i*20,:,:,1]
    plt.imshow(reconstruct_image(x, y),cmap='gist_gray')
    plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# ### Ground truth of x-y-coordinates and display in image space
# Out of all 8 recordings from the dataset one frame is displayed

# %%
for i in range(8):
    val = 441 + i
    plt.subplot(val)
    x = xy_data[i*20,:,:,0]
    y = xy_data[i*20,:,:,1]
    plt.imshow(reconstruct_image(x, y),cmap='gist_gray')
    plt.axis('off')
    plt.tight_layout()

# %% [markdown]
# ## Exemplary smoothing

# %%
from skimage.restoration import denoise_bilateral
plt.rcParams["figure.figsize"] = (7,7)

# %%
x = res_decoder[900,:,:,0]
y = res_decoder[900,:,:,1]

x_smooth = denoise_bilateral(x[1:-1,1:-1],mode='edge',sigma_spatial=100, win_size=3)
y_smooth = denoise_bilateral(y[1:-1,1:-1],mode='edge',sigma_spatial=100, win_size=3)
plt.imshow(reconstruct_image(x_smooth, y_smooth),cmap='gist_gray')

# %% [markdown]
# ## Generate an image based on a vector from the latent space

# %%
# %%capture
# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interact, widgets
from IPython.display import display

def f(**sliders):
    sliders_float = [float(slider[1]) for slider in sliders.items()]
    res_encoder = np.array([sliders_float])
    res_decoder = decoder.predict(res_encoder)
    
    x = res_decoder[0,:,:,0]
    y = res_decoder[0,:,:,1]
    
    img = reconstruct_image(x, y)

    ax.imshow(img, cmap="gray")
    fig.canvas.draw()
    display(fig)

fig = plt.figure(figsize=(6, 4))
ax = fig.add_axes(plt.axes())

sliders = {str(i): widgets.FloatSlider(min=-2.0,max=2.0,step=0.5,value=0.0) for i in range(latent_dim)}

# %%
_ = interact(f, **sliders)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='0', max=2.0, min=-2.0, step=0.5), FloatSlider(value=…
