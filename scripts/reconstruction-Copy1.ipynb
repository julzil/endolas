# %%
from endolas import reconstruction
import json
import numpy as np
import scipy.io
from pdb import set_trace

# %% [markdown]
# # Loads data from keypoints and calibration and carries out reconstruction

# %% [markdown]
# Create a matlab like formed data structure

# %%
calibration = scipy.io.loadmat('roi_2_mat/KK17_experiment_18.mat')

# %%
data = reconstruction.reconstruct_film(calibration, start_row=0, end_row=5)

# %%
data[0].shape
# Out:
# (3, 108)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[0][0,:], data[0][1,:], data[0][2,:])
# Out:
# <img src="data:image/png;base64,..." width="639.85">
