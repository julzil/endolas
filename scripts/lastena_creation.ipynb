# %%
import imageio
import numpy as np
import json
from matplotlib import pyplot as plt
from skimage.transform import warp
from scipy.ndimage import gaussian_filter
from scipy import ndimage
from pdb import set_trace

import glob
import math
import nibabel as nib
import utils
import random
import os

# %%
base_dir = '/home/julian/Documents/Studium/MT-Masterarbeit/Data/LASTENAS'

width = 768
height = 768

n_x = 18
n_y = 18

sample_size = 2160
#sample_size = 10

start_sample = 240
end_sample = start_sample + sample_size

p_dropout = 0.7
p_sinus = 0.7
p_rot = 0.7
p_scale = 0.7
p_shear = 0.7
p_global_trans = 0.7
p_local_trans = 0.7

# -----------
dropout_max = 0.2

x_sin_max = 0.15 * height
y_sin_max = 0.015 * width

rot_max = math.pi * 0.1125 # 22.5 deg

x_scale_max = 1.25
y_scale_max = 1.25

x_shear_max = math.pi * 0.05625 # 11.25 deg
y_shear_max = math.pi * 0.05625 # 11.25 deg

x_global_max = 0.2 * width
y_global_max = 0.2 * height

x_local_max = 0.005 * width
y_local_max = 0.005 * height

# %%
spacing_x = (width / 2.0) / n_x
spacing_y = (height / 2.0) / n_y

base_offset_x = width / 4.0
base_offset_y = height / 4.0

offset_x = spacing_x / 2.0 + base_offset_x
offset_y = spacing_y / 2.0 + base_offset_y

# %%
def random_decision(probability):
    return random.random() < probability

# %%
def apply_sinus(x, y, rand_1, rand_2): 
    y_ratio = (y - offset_y) / (spacing_y * (n_y - 1))
    y_sin = math.sin(y_ratio * math.pi) * y_sin_max * rand_1
    u = x - round(y_sin)
    
    x_ratio = (x - offset_x) / (spacing_x * (n_x - 1))
    x_sin = math.sin(x_ratio * math.pi) * x_sin_max * rand_2
    v = y - round(x_sin)
    
    return u,v

def apply_rot(x, y, rand_1):
    shift_x = round(width / 2)
    shift_y = round(height / 2)
    
    x = x - shift_x
    y = y - shift_y
    
    alpha = rot_max * rand_1
    
    vec = np.array([x, y])
    mat = np.array([[np.cos(alpha), -np.sin(alpha)],
                    [np.sin(alpha), np.cos(alpha)]])

    vec = np.dot(mat, vec)
    
    u = int(round(vec[0]))
    v = int(round(vec[1]))
    
    u = u + shift_x
    v = v + shift_y
    
    return u,v

def apply_scale(x, y, rand_1, rand_2):
    rand_1 = (rand_1 + 1.0) / 2.0
    rand_2 = (rand_1 + 1.0) / 2.0
    
    shift_x = round(width / 2)
    shift_y = round(height / 2)
    
    x = x - shift_x
    y = y - shift_y
    
    x_scale = (1 / x_scale_max) + (x_scale_max - (1 / x_scale_max)) * rand_1
    y_scale = (1 / y_scale_max) + (y_scale_max - (1 / y_scale_max)) * rand_2
    
    vec = np.array([x, y])
    mat = np.array([[x_scale, 0      ],
                    [0      , y_scale]])

    vec = np.dot(mat, vec)
    
    u = int(round(vec[0]))
    v = int(round(vec[1]))
    
    u = u + shift_x
    v = v + shift_y
    
    return u,v

def apply_shear(x, y, rand_1, rand_2):
    shift_x = round(width / 2)
    shift_y = round(height / 2)
    
    x = x - shift_x
    y = y - shift_y
    
    phi = x_shear_max * rand_1
    psi = y_shear_max * rand_2
    
    vec = np.array([x, y])
    mat = np.array([[1          , np.tan(phi)],
                    [np.tan(psi), 1          ]])

    vec = np.dot(mat, vec)
    
    u = int(round(vec[0]))
    v = int(round(vec[1]))
    
    u = u + shift_x
    v = v + shift_y
    
    return u,v

def apply_global_trans(x, y, rand_1, rand_2):
    u = x + round(x_global_max * rand_1)
    v = y + round(y_global_max * rand_2)
    
    return u,v

def apply_local_trans(x, y):
    u = x + round(x_local_max * (random.random() * 2.0 - 1.0))
    v = y + round(y_local_max * (random.random() * 2.0 - 1.0))
    
    return u,v

def apply_dropout(rand):
    dropout = dropout_max * rand
    if random_decision(dropout):
        return True
        
    else:
        return False

# %%
def get_fixed_data(sample_index):
    is_dropout = random_decision(p_dropout)
    
    fixed = np.zeros((height, width))
    index_2_xy = dict()
    index = 0
    rand = random.random()
    for index_y in reversed(range(n_y)):
        y = int(round(offset_y + (spacing_y * index_y)))

        for index_x in range(n_x):
            x = int(round(offset_x + (spacing_x * index_x)))
            
            drop = apply_dropout(rand) if (is_dropout and sample_index!=0) else False
            
            if not drop:
                fixed[y][x] = 1
                index_2_xy[index] = (x, y)
            
            index += 1
            
    return fixed, index_2_xy

# %%
def get_moving_data(rand_1, rand_2, sample_index, index_2_xy):
    is_dropout = random_decision(p_dropout)
    is_sinus = random_decision(p_sinus)
    is_rot = random_decision(p_rot)
    is_scale = random_decision(p_scale)
    is_shear = random_decision(p_shear)
    is_global_trans = random_decision(p_global_trans)
    is_local_trans = random_decision(p_local_trans)
    
    moving = np.zeros((height, width))
    index_2_uv = dict()
    
    rand = random.random()
    
    for index, xy in index_2_xy.items():
        x=xy[0]
        y=xy[1]
            
        drop = apply_dropout(rand) if is_dropout else False
          
        if not drop:
            u = x
            v = y

            #if sample_index != 0:
            if is_sinus: u,v = apply_sinus(u, v, rand_1, rand_2)
            if is_rot: u,v = apply_rot(u, v, rand_1) 
            if is_scale: u,v = apply_scale(u, v, rand_1, rand_2) 
            if is_shear: u,v = apply_shear(u, v, rand_1, rand_2) 
            if is_global_trans: u,v = apply_global_trans(u, v, rand_1, rand_2) 
            if is_local_trans: u,v = apply_local_trans(u, v) 

            if u < 0 or v < 0 or u > (width-1) or v > (height-1):
                print('Additional attempt for sample index "{}"'.format(sample_index))
                return None, None, False

            else:
                moving[v][u] = 1
                index_2_uv[index] = (u, v)
            
    return moving, index_2_uv, True

# %%
available_indices = list(range(start_sample, end_sample))

for set_type in ["train", "test", "validation"]:
    print("Start {}".format(set_type))
    load_dir = base_dir + os.sep + set_type + os.sep
    save_dir = base_dir + os.sep + "aug" + os.sep

    globs = glob.glob(load_dir + "*.json")
    globs = [int(path.split(os.sep)[-1].split(".")[0]) for path in globs]
    image_ids = sorted(globs)

    for image_id in image_ids:
        sample_path = load_dir + "{}.json".format(image_id)
        with open(sample_path) as sample_file:
            sample_json_o = json.load(sample_file)
            sample_json = dict()

            for key, value in sample_json_o.items():
                sample_json[int(key)] = value

        for _ in range(0,9):
            try:
                new_image_id = available_indices.pop(0)
            except IndexError:
                raise AssertionError("Something went wrong when assigning ids")

            index_2_xy = sample_json

            is_valid = False
            while(not is_valid):
                rand_1 = random.random() * 2.0 - 1.0
                rand_2 = random.random() * 2.0 - 1.0

                moving, index_2_uv, is_valid = get_moving_data(rand_1, rand_2, new_image_id, index_2_xy)

            json_file = json.dumps(index_2_uv)
            f = open(save_dir + "{}.json".format(new_image_id), "w")
            f.write(json_file)
            f.close()

            moving = utils.apply_smoothing(moving, sigma=2, sigma_back=15)
            plt.imsave(save_dir + "{}_mov.png".format(new_image_id), moving, cmap="gray")
# Out:
# Start train
# Additional attempt for sample index "245"
# Additional attempt for sample index "247"
# Additional attempt for sample index "247"
# Additional attempt for sample index "257"
# Additional attempt for sample index "274"
# Additional attempt for sample index "296"
# Additional attempt for sample index "297"
# Additional attempt for sample index "324"
# Additional attempt for sample index "345"
# Additional attempt for sample index "379"
# Additional attempt for sample index "432"
# Additional attempt for sample index "434"
# Additional attempt for sample index "439"
# Additional attempt for sample index "440"
# Additional attempt for sample index "454"
# Additional attempt for sample index "458"
# Additional attempt for sample index "516"
# Additional attempt for sample index "526"
# Additional attempt for sample index "528"
# Additional attempt for sample index "558"
# Additional attempt for sample index "579"
# Additional attempt for sample index "599"
# Additional attempt for sample index "604"
# Additional attempt for sample index "608"
# Additional attempt for sample index "611"
# Additional attempt for sample index "635"
# Additional attempt for sample index "678"
# Additional attempt for sample index "692"
# Additional attempt for sample index "714"
# Additional attempt for sample index "721"
# Additional attempt for sample index "786"
# Additional attempt for sample index "836"
# Additional attempt for sample index "836"
# Additional attempt for sample index "838"
# Additional attempt for sample index "841"
# Additional attempt for sample index "843"
# Additional attempt for sample index "854"
# Additional attempt for sample index "936"
# Additional attempt for sample index "965"
# Additional attempt for sample index "972"
# Additional attempt for sample index "975"
# Additional attempt for sample index "984"
# Additional attempt for sample index "985"
# Additional attempt for sample index "1001"
# Additional attempt for sample index "1037"
# Additional attempt for sample index "1045"
# Additional attempt for sample index "1050"
# Additional attempt for sample index "1065"
# Additional attempt for sample index "1075"
# Additional attempt for sample index "1076"
# Additional attempt for sample index "1086"
# Additional attempt for sample index "1086"
# Additional attempt for sample index "1088"
# Additional attempt for sample index "1092"
# Additional attempt for sample index "1106"
# Additional attempt for sample index "1108"
# Additional attempt for sample index "1113"
# Additional attempt for sample index "1120"
# Additional attempt for sample index "1120"
# Additional attempt for sample index "1124"
# Additional attempt for sample index "1124"
# Additional attempt for sample index "1132"
# Additional attempt for sample index "1135"
# Additional attempt for sample index "1147"
# Additional attempt for sample index "1148"
# Additional attempt for sample index "1148"
# Additional attempt for sample index "1153"
# Additional attempt for sample index "1162"
# Additional attempt for sample index "1164"
# Additional attempt for sample index "1165"
# Additional attempt for sample index "1165"
# Additional attempt for sample index "1168"
# Additional attempt for sample index "1168"
# Additional attempt for sample index "1170"
# Additional attempt for sample index "1171"
# Additional attempt for sample index "1171"
# Additional attempt for sample index "1175"
# Additional attempt for sample index "1175"
# Additional attempt for sample index "1176"
# Additional attempt for sample index "1181"
# Additional attempt for sample index "1184"
# Additional attempt for sample index "1186"
# Additional attempt for sample index "1186"
# Additional attempt for sample index "1186"
# Additional attempt for sample index "1186"
# Additional attempt for sample index "1186"
# Additional attempt for sample index "1188"
# Additional attempt for sample index "1188"
# Additional attempt for sample index "1188"
# Additional attempt for sample index "1191"
# Additional attempt for sample index "1198"
# Additional attempt for sample index "1206"
# Additional attempt for sample index "1206"
# Additional attempt for sample index "1207"
# Additional attempt for sample index "1207"
# Additional attempt for sample index "1207"
# Additional attempt for sample index "1207"
# Additional attempt for sample index "1207"
# Additional attempt for sample index "1210"
# Additional attempt for sample index "1213"
# Additional attempt for sample index "1214"
# Additional attempt for sample index "1214"
# Additional attempt for sample index "1214"
# Additional attempt for sample index "1216"
# Additional attempt for sample index "1217"
# Additional attempt for sample index "1225"
# Additional attempt for sample index "1226"
# Additional attempt for sample index "1231"
# Additional attempt for sample index "1231"
# Additional attempt for sample index "1232"
# Additional attempt for sample index "1235"
# Additional attempt for sample index "1235"
# Additional attempt for sample index "1236"
# Additional attempt for sample index "1236"
# Additional attempt for sample index "1239"
# Additional attempt for sample index "1247"
# Additional attempt for sample index "1249"
# Additional attempt for sample index "1251"
# Additional attempt for sample index "1254"
# Additional attempt for sample index "1255"
# Additional attempt for sample index "1264"
# Additional attempt for sample index "1265"
# Additional attempt for sample index "1266"
# Additional attempt for sample index "1267"
# Additional attempt for sample index "1284"
# Additional attempt for sample index "1285"
# Additional attempt for sample index "1293"
# Additional attempt for sample index "1293"
# Additional attempt for sample index "1303"
# Additional attempt for sample index "1306"
# Additional attempt for sample index "1306"
# Additional attempt for sample index "1320"
# Additional attempt for sample index "1323"
# Additional attempt for sample index "1326"
# Additional attempt for sample index "1328"
# Additional attempt for sample index "1335"
# Additional attempt for sample index "1338"
# Additional attempt for sample index "1348"
# Additional attempt for sample index "1350"
# Additional attempt for sample index "1355"
# Additional attempt for sample index "1359"
# Additional attempt for sample index "1370"
# Additional attempt for sample index "1370"
# Additional attempt for sample index "1389"
# Additional attempt for sample index "1390"
# Additional attempt for sample index "1390"
# Additional attempt for sample index "1407"
# Additional attempt for sample index "1410"
# Additional attempt for sample index "1424"
# Additional attempt for sample index "1427"
# Additional attempt for sample index "1428"
# Additional attempt for sample index "1430"
# Additional attempt for sample index "1436"
# Additional attempt for sample index "1436"
# Additional attempt for sample index "1436"
# Additional attempt for sample index "1441"
# Additional attempt for sample index "1441"
# Additional attempt for sample index "1441"
# Additional attempt for sample index "1449"
# Additional attempt for sample index "1456"
# Additional attempt for sample index "1459"
# Additional attempt for sample index "1459"
# Additional attempt for sample index "1464"
# Additional attempt for sample index "1466"
# Additional attempt for sample index "1466"
# Additional attempt for sample index "1468"
# Additional attempt for sample index "1471"
# Additional attempt for sample index "1473"
# Additional attempt for sample index "1475"
# Additional attempt for sample index "1476"
# Additional attempt for sample index "1476"
# Additional attempt for sample index "1477"
# Additional attempt for sample index "1479"
# Additional attempt for sample index "1483"
# Additional attempt for sample index "1485"
# Additional attempt for sample index "1487"
# Additional attempt for sample index "1490"
# Additional attempt for sample index "1495"
# Additional attempt for sample index "1496"
# Additional attempt for sample index "1496"
# Additional attempt for sample index "1497"
# Additional attempt for sample index "1505"
# Additional attempt for sample index "1526"
# Additional attempt for sample index "1529"
# Additional attempt for sample index "1537"
# Additional attempt for sample index "1550"
# Additional attempt for sample index "1550"
# Additional attempt for sample index "1550"
# Additional attempt for sample index "1550"
# Additional attempt for sample index "1555"
# Additional attempt for sample index "1561"
# Additional attempt for sample index "1572"
# Additional attempt for sample index "1574"
# Additional attempt for sample index "1574"
# Additional attempt for sample index "1580"
# Additional attempt for sample index "1582"
# Additional attempt for sample index "1587"
# Additional attempt for sample index "1594"
# Additional attempt for sample index "1594"
# Additional attempt for sample index "1599"
# Additional attempt for sample index "1617"
# Additional attempt for sample index "1620"
# Additional attempt for sample index "1620"
# Additional attempt for sample index "1731"
# Additional attempt for sample index "1742"
# Start test
# Additional attempt for sample index "1771"
# Additional attempt for sample index "1804"
# Additional attempt for sample index "1830"
# Additional attempt for sample index "1851"
# Additional attempt for sample index "1891"
# Additional attempt for sample index "1897"
# Additional attempt for sample index "1951"
# Additional attempt for sample index "1952"
# Additional attempt for sample index "1953"
# Additional attempt for sample index "1956"
# Additional attempt for sample index "1957"
# Additional attempt for sample index "1957"
# Additional attempt for sample index "1958"
# Additional attempt for sample index "1958"
# Additional attempt for sample index "1963"
# Additional attempt for sample index "1969"
# Additional attempt for sample index "1970"
# Additional attempt for sample index "1971"
# Additional attempt for sample index "1975"
# Additional attempt for sample index "1976"
# Additional attempt for sample index "1983"
# Additional attempt for sample index "1984"
# Additional attempt for sample index "2004"
# Additional attempt for sample index "2004"
# Additional attempt for sample index "2008"
# Additional attempt for sample index "2009"
# Additional attempt for sample index "2014"
# Additional attempt for sample index "2015"
# Additional attempt for sample index "2021"
# Additional attempt for sample index "2021"
# Additional attempt for sample index "2021"
# Additional attempt for sample index "2022"
# Additional attempt for sample index "2024"
# Additional attempt for sample index "2024"
# Additional attempt for sample index "2025"
# Additional attempt for sample index "2038"
# Additional attempt for sample index "2044"
# Additional attempt for sample index "2045"
# Additional attempt for sample index "2046"
# Additional attempt for sample index "2050"
# Additional attempt for sample index "2056"
# Start validation
# Additional attempt for sample index "2085"
# Additional attempt for sample index "2091"
# Additional attempt for sample index "2094"
# Additional attempt for sample index "2123"
# Additional attempt for sample index "2176"
# Additional attempt for sample index "2274"
# Additional attempt for sample index "2281"
# Additional attempt for sample index "2286"
# Additional attempt for sample index "2286"
# Additional attempt for sample index "2289"
# Additional attempt for sample index "2289"
# Additional attempt for sample index "2290"
# Additional attempt for sample index "2292"
# Additional attempt for sample index "2293"
# Additional attempt for sample index "2295"
# Additional attempt for sample index "2297"
# Additional attempt for sample index "2300"
# Additional attempt for sample index "2301"
# Additional attempt for sample index "2301"
# Additional attempt for sample index "2308"
# Additional attempt for sample index "2309"
# Additional attempt for sample index "2311"
# Additional attempt for sample index "2311"
# Additional attempt for sample index "2314"
# Additional attempt for sample index "2314"
# Additional attempt for sample index "2318"
# Additional attempt for sample index "2322"
# Additional attempt for sample index "2323"
# Additional attempt for sample index "2328"
# Additional attempt for sample index "2328"
# Additional attempt for sample index "2328"
# Additional attempt for sample index "2333"
# Additional attempt for sample index "2333"
# Additional attempt for sample index "2334"
# Additional attempt for sample index "2335"
# Additional attempt for sample index "2336"
# Additional attempt for sample index "2336"
# Additional attempt for sample index "2342"
# Additional attempt for sample index "2342"
# Additional attempt for sample index "2344"
# Additional attempt for sample index "2351"
# Additional attempt for sample index "2377"
# Additional attempt for sample index "2393"

# %%
available_indices
# Out:
# []

# %%
# Image 0 will always be in the training
shuffled_list = list(range(start_sample, end_sample))
random.shuffle(shuffled_list)

if sample_size*0.15 % 1 > 0.0:
    raise AssertionError("Sample needs different split")

train_part = int(sample_size * 0.7)
val_part = int(sample_size * 0.15)
test_part = int(sample_size * 0.15)

train = shuffled_list[0:train_part] # 70 percent training
validation = shuffled_list[train_part:train_part+val_part] # 15 percent training
test = shuffled_list[train_part+val_part:sample_size] # 15 percent training

# %%
available_indices
# Out:
# []

# %%
for index in train:
    moving_sou = os.path.join(base_dir, "aug", "{}_mov.png".format(index))
    moving_json_sou = os.path.join(base_dir, "aug", "{}.json".format(index))
    
    moving_des = os.path.join(base_dir, "train", "{}_mov.png".format(index))
    moving_json_des = os.path.join(base_dir, "train", "{}.json".format(index))
    
    os.rename(moving_sou, moving_des)
    os.rename(moving_json_sou, moving_json_des)

# %%
for index in validation:
    moving_sou = os.path.join(base_dir, "aug", "{}_mov.png".format(index))
    moving_json_sou = os.path.join(base_dir, "aug", "{}.json".format(index))
    
    moving_des = os.path.join(base_dir, "validation", "{}_mov.png".format(index))
    moving_json_des = os.path.join(base_dir, "validation", "{}.json".format(index))
    
    os.rename(moving_sou, moving_des)
    os.rename(moving_json_sou, moving_json_des)

# %%
for index in test:
    moving_sou = os.path.join(base_dir, "aug", "{}_mov.png".format(index))
    moving_json_sou = os.path.join(base_dir, "aug", "{}.json".format(index))
    
    moving_des = os.path.join(base_dir, "test", "{}_mov.png".format(index))
    moving_json_des = os.path.join(base_dir, "test", "{}.json".format(index))
    
    os.rename(moving_sou, moving_des)
    os.rename(moving_json_sou, moving_json_des)
